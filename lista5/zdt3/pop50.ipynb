# %% [markdown]
# # Optymalizacja wielokryterialna
#
# Notebook pokazuje przykład działania algorytmu NSGA-II na benchmarku ZDT3.
#
# Literatura dodatkowa:
#
# [1] E. Zitzler, K. Deb, L. Thiele, Comparison of Multiobjective Evolutionary Algorithms: Empirical Results, Evolutionary Computation, vol 8, no 2, 2000, pp. 173-195. [http://www.tik.ee.ethz.ch/sop/publicationListFiles/zdt2000a.pdf]
#
# [2] Multi-objective Benchmark Problems. [http://www.tik.ee.ethz.ch/sop/download/supplementary/testproblems/]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Działanie NSGA-II na ZDT3

# %% [markdown]
# ### Problem ZDT3
#
# Problem ZDT3 to dość popularny problem testowy dla optymalizacji wielokryterialnej.
#
# Przestrzeń poszukiwań: $\Omega = [0, 1]^d$.
#
# Dwa kryteria (oba minimalizujemy):
#
# $$f_1(\mathbf{x}) = x_1,$$
#
# $$f_2(\mathbf{x}) = g(\mathbf{x}) [1 - \sqrt{x_1 / g(\mathbf{x})} - x_1 / g(\mathbf{x}) \sin(10 \pi x_1)],$$
# gdzie $g(\mathbf{x}) = 1 + \frac{9}{d-1}\sum_{i=2}^d x_i$.

# %% [markdown]
# ### Dokładny front Pareto dla ZDT3
#
# Znane są wzory na dokładny front Pareto dla ZDT3 (patrz [1] lub [2]).

# %%
F = np.array([[0.0000000000, 0.0830015349],
              [0.1822287280, 0.2577623634],
              [0.4093136748, 0.4538821041],
              [0.6183967944, 0.6525117038],
              [0.8233317983, 0.8518328654]])

r = 10
X = (np.tile(np.linspace(0, 1, r), [F.shape[0], 1]) * (F[:, 1] - F[:, 0])[np.newaxis].T + F[:, 0][np.newaxis].T)
Y = 1 - np.sqrt(X) - X * np.sin(10 * np.pi * X)

plt.figure(figsize=(12, 8))
for i in xrange(F.shape[0]):
    plt.plot(X[i, :].ravel(), Y[i, :].ravel(), 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT3Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt3_definitions import ZDT3Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT3Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = []
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT3Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics.append((hv, hvr, ranks, crowding_distances, objectives))

# %%
def plot_PF(results):
    PF = np.array([i.objectives for i in results])

    plt.figure(figsize=(12, 8))
    plt.plot(PF[:, 0], PF[:, 1], 'ro')
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.title('Pareto Front')
    plt.show()

# %%
# %%time

solver = Evolution(ZDT(ZDT3Definitions()), 500, 50)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()

plot_PF(results)
# Out:
# Iteration 000: HV = 77.62, HVR = 0.60
# Iteration 001: HV = 75.91, HVR = 0.59
# Iteration 002: HV = 77.08, HVR = 0.60
# Iteration 003: HV = 77.88, HVR = 0.60
# Iteration 004: HV = 79.26, HVR = 0.62
# Iteration 005: HV = 79.80, HVR = 0.62
# Iteration 006: HV = 80.80, HVR = 0.63
# Iteration 007: HV = 81.26, HVR = 0.63
# Iteration 008: HV = 81.36, HVR = 0.63
# Iteration 009: HV = 82.65, HVR = 0.64
# Iteration 010: HV = 82.79, HVR = 0.64
# Iteration 011: HV = 83.70, HVR = 0.65
# Iteration 012: HV = 83.99, HVR = 0.65
# Iteration 013: HV = 86.50, HVR = 0.67
# Iteration 014: HV = 85.53, HVR = 0.66
# Iteration 015: HV = 86.86, HVR = 0.67
# Iteration 016: HV = 86.87, HVR = 0.67
# Iteration 017: HV = 89.14, HVR = 0.69
# Iteration 018: HV = 89.59, HVR = 0.70
# Iteration 019: HV = 91.53, HVR = 0.71
# Iteration 020: HV = 91.79, HVR = 0.71
# Iteration 021: HV = 91.97, HVR = 0.71
# Iteration 022: HV = 93.39, HVR = 0.73
# Iteration 023: HV = 94.75, HVR = 0.74
# Iteration 024: HV = 95.22, HVR = 0.74
# Iteration 025: HV = 94.35, HVR = 0.73
# Iteration 026: HV = 95.31, HVR = 0.74
# Iteration 027: HV = 95.24, HVR = 0.74
# Iteration 028: HV = 95.81, HVR = 0.74
# Iteration 029: HV = 96.14, HVR = 0.75
# Iteration 030: HV = 97.01, HVR = 0.75
# Iteration 031: HV = 98.62, HVR = 0.77
# Iteration 032: HV = 98.93, HVR = 0.77
# Iteration 033: HV = 99.30, HVR = 0.77
# Iteration 034: HV = 99.34, HVR = 0.77
# Iteration 035: HV = 100.37, HVR = 0.78
# Iteration 036: HV = 100.76, HVR = 0.78
# Iteration 037: HV = 101.58, HVR = 0.79
# Iteration 038: HV = 101.36, HVR = 0.79
# Iteration 039: HV = 101.58, HVR = 0.79
# Iteration 040: HV = 101.79, HVR = 0.79
# Iteration 041: HV = 102.36, HVR = 0.79
# Iteration 042: HV = 102.30, HVR = 0.79
# Iteration 043: HV = 103.07, HVR = 0.80
# Iteration 044: HV = 103.32, HVR = 0.80
# Iteration 045: HV = 103.63, HVR = 0.80
# Iteration 046: HV = 104.11, HVR = 0.81
# Iteration 047: HV = 104.09, HVR = 0.81
# Iteration 048: HV = 104.90, HVR = 0.81
# Iteration 049: HV = 104.47, HVR = 0.81
# Iteration 050: HV = 104.52, HVR = 0.81
# Iteration 051: HV = 104.61, HVR = 0.81
# Iteration 052: HV = 104.54, HVR = 0.81
# Iteration 053: HV = 105.42, HVR = 0.82
# Iteration 054: HV = 105.59, HVR = 0.82
# Iteration 055: HV = 105.82, HVR = 0.82
# Iteration 056: HV = 105.89, HVR = 0.82
# Iteration 057: HV = 105.98, HVR = 0.82
# Iteration 058: HV = 105.99, HVR = 0.82
# Iteration 059: HV = 106.68, HVR = 0.83
# Iteration 060: HV = 106.55, HVR = 0.83
# Iteration 061: HV = 106.99, HVR = 0.83
# Iteration 062: HV = 107.18, HVR = 0.83
# Iteration 063: HV = 107.17, HVR = 0.83
# Iteration 064: HV = 107.23, HVR = 0.83
# Iteration 065: HV = 107.41, HVR = 0.83
# Iteration 066: HV = 107.80, HVR = 0.84
# Iteration 067: HV = 107.86, HVR = 0.84
# Iteration 068: HV = 107.98, HVR = 0.84
# Iteration 069: HV = 108.28, HVR = 0.84
# Iteration 070: HV = 108.85, HVR = 0.85
# Iteration 071: HV = 108.98, HVR = 0.85
# Iteration 072: HV = 108.71, HVR = 0.84
# Iteration 073: HV = 108.81, HVR = 0.84
# Iteration 074: HV = 108.78, HVR = 0.84
# Iteration 075: HV = 108.89, HVR = 0.85
# Iteration 076: HV = 108.93, HVR = 0.85
# Iteration 077: HV = 109.09, HVR = 0.85
# Iteration 078: HV = 109.12, HVR = 0.85
# Iteration 079: HV = 109.34, HVR = 0.85
# Iteration 080: HV = 109.43, HVR = 0.85
# Iteration 081: HV = 109.59, HVR = 0.85
# Iteration 082: HV = 109.75, HVR = 0.85
# Iteration 083: HV = 109.83, HVR = 0.85
# Iteration 084: HV = 109.97, HVR = 0.85
# Iteration 085: HV = 109.99, HVR = 0.85
# Iteration 086: HV = 110.11, HVR = 0.86
# Iteration 087: HV = 110.27, HVR = 0.86
# Iteration 088: HV = 110.29, HVR = 0.86
# Iteration 089: HV = 110.53, HVR = 0.86
# Iteration 090: HV = 110.63, HVR = 0.86
# Iteration 091: HV = 110.67, HVR = 0.86
# Iteration 092: HV = 110.70, HVR = 0.86
# Iteration 093: HV = 110.48, HVR = 0.86
# Iteration 094: HV = 110.55, HVR = 0.86
# Iteration 095: HV = 110.67, HVR = 0.86
# Iteration 096: HV = 110.69, HVR = 0.86
# Iteration 097: HV = 111.03, HVR = 0.86
# Iteration 098: HV = 111.24, HVR = 0.86
# Iteration 099: HV = 111.29, HVR = 0.86
# Iteration 100: HV = 111.68, HVR = 0.87
# Iteration 101: HV = 111.55, HVR = 0.87
# Iteration 102: HV = 111.63, HVR = 0.87
# Iteration 103: HV = 111.59, HVR = 0.87
# Iteration 104: HV = 111.58, HVR = 0.87
# Iteration 105: HV = 111.93, HVR = 0.87
# Iteration 106: HV = 111.89, HVR = 0.87
# Iteration 107: HV = 111.67, HVR = 0.87
# Iteration 108: HV = 111.69, HVR = 0.87
# Iteration 109: HV = 111.77, HVR = 0.87
# Iteration 110: HV = 111.92, HVR = 0.87
# Iteration 111: HV = 112.04, HVR = 0.87
# Iteration 112: HV = 112.21, HVR = 0.87
# Iteration 113: HV = 112.27, HVR = 0.87
# Iteration 114: HV = 112.15, HVR = 0.87
# Iteration 115: HV = 112.39, HVR = 0.87
# Iteration 116: HV = 112.51, HVR = 0.87
# Iteration 117: HV = 112.56, HVR = 0.87
# Iteration 118: HV = 112.60, HVR = 0.87
# Iteration 119: HV = 112.59, HVR = 0.87
# Iteration 120: HV = 112.64, HVR = 0.87
# Iteration 121: HV = 112.62, HVR = 0.87
# Iteration 122: HV = 112.70, HVR = 0.88
# Iteration 123: HV = 112.79, HVR = 0.88
# Iteration 124: HV = 112.79, HVR = 0.88
# Iteration 125: HV = 112.82, HVR = 0.88
# Iteration 126: HV = 112.84, HVR = 0.88
# Iteration 127: HV = 113.03, HVR = 0.88
# Iteration 128: HV = 113.25, HVR = 0.88
# Iteration 129: HV = 113.28, HVR = 0.88
# Iteration 130: HV = 113.44, HVR = 0.88
# Iteration 131: HV = 113.45, HVR = 0.88
# Iteration 132: HV = 113.49, HVR = 0.88
# Iteration 133: HV = 113.53, HVR = 0.88
# Iteration 134: HV = 113.29, HVR = 0.88
# Iteration 135: HV = 113.47, HVR = 0.88
# Iteration 136: HV = 113.51, HVR = 0.88
# Iteration 137: HV = 113.60, HVR = 0.88
# Iteration 138: HV = 113.55, HVR = 0.88
# Iteration 139: HV = 113.66, HVR = 0.88
# Iteration 140: HV = 113.69, HVR = 0.88
# Iteration 141: HV = 113.69, HVR = 0.88
# Iteration 142: HV = 113.71, HVR = 0.88
# Iteration 143: HV = 113.64, HVR = 0.88
# Iteration 144: HV = 113.56, HVR = 0.88
# Iteration 145: HV = 113.51, HVR = 0.88
# Iteration 146: HV = 113.62, HVR = 0.88
# Iteration 147: HV = 113.67, HVR = 0.88
# Iteration 148: HV = 113.81, HVR = 0.88
# Iteration 149: HV = 113.85, HVR = 0.88
# Iteration 150: HV = 113.95, HVR = 0.88
# Iteration 151: HV = 114.15, HVR = 0.89
# Iteration 152: HV = 114.25, HVR = 0.89
# Iteration 153: HV = 114.35, HVR = 0.89
# Iteration 154: HV = 114.35, HVR = 0.89
# Iteration 155: HV = 114.37, HVR = 0.89
# Iteration 156: HV = 114.41, HVR = 0.89
# Iteration 157: HV = 114.41, HVR = 0.89
# Iteration 158: HV = 114.29, HVR = 0.89
# Iteration 159: HV = 114.28, HVR = 0.89
# Iteration 160: HV = 114.29, HVR = 0.89
# Iteration 161: HV = 114.27, HVR = 0.89
# Iteration 162: HV = 114.26, HVR = 0.89
# Iteration 163: HV = 114.17, HVR = 0.89
# Iteration 164: HV = 114.13, HVR = 0.89
# Iteration 165: HV = 114.15, HVR = 0.89
# Iteration 166: HV = 114.08, HVR = 0.89
# Iteration 167: HV = 114.04, HVR = 0.89
# Iteration 168: HV = 114.00, HVR = 0.89
# Iteration 169: HV = 114.02, HVR = 0.89
# Iteration 170: HV = 113.93, HVR = 0.88
# Iteration 171: HV = 113.94, HVR = 0.88
# Iteration 172: HV = 113.81, HVR = 0.88
# Iteration 173: HV = 113.79, HVR = 0.88
# Iteration 174: HV = 113.83, HVR = 0.88
# Iteration 175: HV = 113.88, HVR = 0.88
# Iteration 176: HV = 113.89, HVR = 0.88
# Iteration 177: HV = 113.87, HVR = 0.88
# Iteration 178: HV = 113.87, HVR = 0.88
# Iteration 179: HV = 113.84, HVR = 0.88
# Iteration 180: HV = 113.85, HVR = 0.88
# Iteration 181: HV = 113.74, HVR = 0.88
# Iteration 182: HV = 113.75, HVR = 0.88
# Iteration 183: HV = 113.81, HVR = 0.88
# Iteration 184: HV = 113.79, HVR = 0.88
# Iteration 185: HV = 113.85, HVR = 0.88
# Iteration 186: HV = 113.85, HVR = 0.88
# Iteration 187: HV = 113.93, HVR = 0.88
# Iteration 188: HV = 113.93, HVR = 0.88
# Iteration 189: HV = 113.99, HVR = 0.89
# Iteration 190: HV = 114.00, HVR = 0.89
# Iteration 191: HV = 114.01, HVR = 0.89
# Iteration 192: HV = 114.01, HVR = 0.89
# Iteration 193: HV = 114.05, HVR = 0.89
# Iteration 194: HV = 113.95, HVR = 0.88
# Iteration 195: HV = 113.86, HVR = 0.88
# Iteration 196: HV = 113.86, HVR = 0.88
# Iteration 197: HV = 113.85, HVR = 0.88
# Iteration 198: HV = 113.94, HVR = 0.88
# Iteration 199: HV = 114.10, HVR = 0.89
# Iteration 200: HV = 114.18, HVR = 0.89
# Iteration 201: HV = 114.22, HVR = 0.89
# Iteration 202: HV = 114.22, HVR = 0.89
# Iteration 203: HV = 114.17, HVR = 0.89
# Iteration 204: HV = 114.15, HVR = 0.89
# Iteration 205: HV = 114.15, HVR = 0.89
# Iteration 206: HV = 114.17, HVR = 0.89
# Iteration 207: HV = 114.16, HVR = 0.89
# Iteration 208: HV = 114.16, HVR = 0.89
# Iteration 209: HV = 114.21, HVR = 0.89
# Iteration 210: HV = 114.06, HVR = 0.89
# Iteration 211: HV = 114.25, HVR = 0.89
# Iteration 212: HV = 114.27, HVR = 0.89
# Iteration 213: HV = 114.22, HVR = 0.89
# Iteration 214: HV = 114.34, HVR = 0.89
# Iteration 215: HV = 114.17, HVR = 0.89
# Iteration 216: HV = 114.16, HVR = 0.89
# Iteration 217: HV = 114.15, HVR = 0.89
# Iteration 218: HV = 113.99, HVR = 0.89
# Iteration 219: HV = 114.11, HVR = 0.89
# Iteration 220: HV = 114.00, HVR = 0.89
# Iteration 221: HV = 114.00, HVR = 0.89
# Iteration 222: HV = 113.86, HVR = 0.88
# Iteration 223: HV = 113.86, HVR = 0.88
# Iteration 224: HV = 113.87, HVR = 0.88
# Iteration 225: HV = 113.77, HVR = 0.88
# Iteration 226: HV = 113.76, HVR = 0.88
# Iteration 227: HV = 113.73, HVR = 0.88
# Iteration 228: HV = 113.71, HVR = 0.88
# Iteration 229: HV = 113.83, HVR = 0.88
# Iteration 230: HV = 113.82, HVR = 0.88
# Iteration 231: HV = 113.83, HVR = 0.88
# Iteration 232: HV = 113.85, HVR = 0.88
# Iteration 233: HV = 113.92, HVR = 0.88
# Iteration 234: HV = 113.89, HVR = 0.88
# Iteration 235: HV = 113.94, HVR = 0.88
# Iteration 236: HV = 113.94, HVR = 0.88
# Iteration 237: HV = 113.99, HVR = 0.89
# Iteration 238: HV = 114.02, HVR = 0.89
# Iteration 239: HV = 114.04, HVR = 0.89
# Iteration 240: HV = 114.02, HVR = 0.89
# Iteration 241: HV = 114.02, HVR = 0.89
# Iteration 242: HV = 113.94, HVR = 0.88
# Iteration 243: HV = 113.85, HVR = 0.88
# Iteration 244: HV = 113.98, HVR = 0.89
# Iteration 245: HV = 113.98, HVR = 0.89
# Iteration 246: HV = 113.92, HVR = 0.88
# Iteration 247: HV = 113.98, HVR = 0.89
# Iteration 248: HV = 113.91, HVR = 0.88
# Iteration 249: HV = 113.83, HVR = 0.88
# Iteration 250: HV = 113.85, HVR = 0.88
# Iteration 251: HV = 113.73, HVR = 0.88
# Iteration 252: HV = 113.77, HVR = 0.88
# Iteration 253: HV = 113.82, HVR = 0.88
# Iteration 254: HV = 113.82, HVR = 0.88
# Iteration 255: HV = 113.85, HVR = 0.88
# Iteration 256: HV = 113.89, HVR = 0.88
# Iteration 257: HV = 113.79, HVR = 0.88
# Iteration 258: HV = 113.71, HVR = 0.88
# Iteration 259: HV = 113.71, HVR = 0.88
# Iteration 260: HV = 113.73, HVR = 0.88
# Iteration 261: HV = 113.70, HVR = 0.88
# Iteration 262: HV = 113.77, HVR = 0.88
# Iteration 263: HV = 113.84, HVR = 0.88
# Iteration 264: HV = 113.85, HVR = 0.88
# Iteration 265: HV = 113.85, HVR = 0.88
# Iteration 266: HV = 113.78, HVR = 0.88
# Iteration 267: HV = 113.81, HVR = 0.88
# Iteration 268: HV = 113.82, HVR = 0.88
# Iteration 269: HV = 113.86, HVR = 0.88
# Iteration 270: HV = 113.91, HVR = 0.88
# Iteration 271: HV = 113.88, HVR = 0.88
# Iteration 272: HV = 113.96, HVR = 0.88
# Iteration 273: HV = 114.05, HVR = 0.89
# Iteration 274: HV = 114.17, HVR = 0.89
# Iteration 275: HV = 114.10, HVR = 0.89
# Iteration 276: HV = 114.25, HVR = 0.89
# Iteration 277: HV = 114.11, HVR = 0.89
# Iteration 278: HV = 114.27, HVR = 0.89
# Iteration 279: HV = 114.08, HVR = 0.89
# Iteration 280: HV = 114.02, HVR = 0.89
# Iteration 281: HV = 114.08, HVR = 0.89
# Iteration 282: HV = 114.18, HVR = 0.89
# Iteration 283: HV = 114.01, HVR = 0.89
# Iteration 284: HV = 114.17, HVR = 0.89
# Iteration 285: HV = 114.24, HVR = 0.89
# Iteration 286: HV = 114.33, HVR = 0.89
# Iteration 287: HV = 114.29, HVR = 0.89
# Iteration 288: HV = 114.23, HVR = 0.89
# Iteration 289: HV = 114.35, HVR = 0.89
# Iteration 290: HV = 114.12, HVR = 0.89
# Iteration 291: HV = 114.16, HVR = 0.89
# Iteration 292: HV = 114.26, HVR = 0.89
# Iteration 293: HV = 114.18, HVR = 0.89
# Iteration 294: HV = 114.11, HVR = 0.89
# Iteration 295: HV = 114.20, HVR = 0.89
# Iteration 296: HV = 114.02, HVR = 0.89
# Iteration 297: HV = 113.92, HVR = 0.88
# Iteration 298: HV = 113.86, HVR = 0.88
# Iteration 299: HV = 113.86, HVR = 0.88
# Iteration 300: HV = 113.89, HVR = 0.88
# Iteration 301: HV = 113.79, HVR = 0.88
# Iteration 302: HV = 113.84, HVR = 0.88
# Iteration 303: HV = 113.79, HVR = 0.88
# Iteration 304: HV = 113.81, HVR = 0.88
# Iteration 305: HV = 113.77, HVR = 0.88
# Iteration 306: HV = 113.75, HVR = 0.88
# Iteration 307: HV = 113.83, HVR = 0.88
# Iteration 308: HV = 113.95, HVR = 0.88
# Iteration 309: HV = 114.06, HVR = 0.89
# Iteration 310: HV = 114.13, HVR = 0.89
# Iteration 311: HV = 114.10, HVR = 0.89
# Iteration 312: HV = 114.04, HVR = 0.89
# Iteration 313: HV = 114.02, HVR = 0.89
# Iteration 314: HV = 114.03, HVR = 0.89
# Iteration 315: HV = 114.03, HVR = 0.89
# Iteration 316: HV = 113.98, HVR = 0.89
# Iteration 317: HV = 114.11, HVR = 0.89
# Iteration 318: HV = 114.16, HVR = 0.89
# Iteration 319: HV = 114.38, HVR = 0.89
# Iteration 320: HV = 114.40, HVR = 0.89
# Iteration 321: HV = 114.33, HVR = 0.89
# Iteration 322: HV = 114.38, HVR = 0.89
# Iteration 323: HV = 114.48, HVR = 0.89
# Iteration 324: HV = 114.49, HVR = 0.89
# Iteration 325: HV = 114.49, HVR = 0.89
# Iteration 326: HV = 114.45, HVR = 0.89
# Iteration 327: HV = 114.38, HVR = 0.89
# Iteration 328: HV = 114.50, HVR = 0.89
# Iteration 329: HV = 114.24, HVR = 0.89
# Iteration 330: HV = 114.16, HVR = 0.89
# Iteration 331: HV = 114.11, HVR = 0.89
# Iteration 332: HV = 113.99, HVR = 0.89
# Iteration 333: HV = 113.85, HVR = 0.88
# Iteration 334: HV = 113.98, HVR = 0.89
# Iteration 335: HV = 114.09, HVR = 0.89
# Iteration 336: HV = 114.07, HVR = 0.89
# Iteration 337: HV = 114.08, HVR = 0.89
# Iteration 338: HV = 114.06, HVR = 0.89
# Iteration 339: HV = 114.12, HVR = 0.89
# Iteration 340: HV = 114.14, HVR = 0.89
# Iteration 341: HV = 114.09, HVR = 0.89
# Iteration 342: HV = 114.07, HVR = 0.89
# Iteration 343: HV = 114.10, HVR = 0.89
# Iteration 344: HV = 113.97, HVR = 0.89
# Iteration 345: HV = 114.05, HVR = 0.89
# Iteration 346: HV = 113.93, HVR = 0.88
# Iteration 347: HV = 113.90, HVR = 0.88
# Iteration 348: HV = 114.12, HVR = 0.89
# Iteration 349: HV = 114.04, HVR = 0.89
# Iteration 350: HV = 114.02, HVR = 0.89
# Iteration 351: HV = 113.91, HVR = 0.88
# Iteration 352: HV = 114.00, HVR = 0.89
# Iteration 353: HV = 113.89, HVR = 0.88
# Iteration 354: HV = 113.89, HVR = 0.88
# Iteration 355: HV = 113.97, HVR = 0.88
# Iteration 356: HV = 113.96, HVR = 0.88
# Iteration 357: HV = 113.74, HVR = 0.88
# Iteration 358: HV = 113.76, HVR = 0.88
# Iteration 359: HV = 113.80, HVR = 0.88
# Iteration 360: HV = 113.79, HVR = 0.88
# Iteration 361: HV = 113.82, HVR = 0.88
# Iteration 362: HV = 113.80, HVR = 0.88
# Iteration 363: HV = 113.79, HVR = 0.88
# Iteration 364: HV = 113.93, HVR = 0.88
# Iteration 365: HV = 113.81, HVR = 0.88
# Iteration 366: HV = 113.81, HVR = 0.88
# Iteration 367: HV = 113.75, HVR = 0.88
# Iteration 368: HV = 113.61, HVR = 0.88
# Iteration 369: HV = 113.57, HVR = 0.88
# Iteration 370: HV = 113.58, HVR = 0.88
# Iteration 371: HV = 113.61, HVR = 0.88
# Iteration 372: HV = 113.73, HVR = 0.88
# Iteration 373: HV = 113.56, HVR = 0.88
# Iteration 374: HV = 113.59, HVR = 0.88
# Iteration 375: HV = 113.61, HVR = 0.88
# Iteration 376: HV = 113.41, HVR = 0.88
# Iteration 377: HV = 113.63, HVR = 0.88
# Iteration 378: HV = 113.55, HVR = 0.88
# Iteration 379: HV = 113.65, HVR = 0.88
# Iteration 380: HV = 113.64, HVR = 0.88
# Iteration 381: HV = 113.46, HVR = 0.88
# Iteration 382: HV = 113.37, HVR = 0.88
# Iteration 383: HV = 113.43, HVR = 0.88
# Iteration 384: HV = 113.28, HVR = 0.88
# Iteration 385: HV = 113.38, HVR = 0.88
# Iteration 386: HV = 113.30, HVR = 0.88
# Iteration 387: HV = 113.30, HVR = 0.88
# Iteration 388: HV = 113.28, HVR = 0.88
# Iteration 389: HV = 113.28, HVR = 0.88
# Iteration 390: HV = 113.32, HVR = 0.88
# Iteration 391: HV = 113.32, HVR = 0.88
# Iteration 392: HV = 113.35, HVR = 0.88
# Iteration 393: HV = 113.33, HVR = 0.88
# Iteration 394: HV = 113.49, HVR = 0.88
# Iteration 395: HV = 113.51, HVR = 0.88
# Iteration 396: HV = 113.37, HVR = 0.88
# Iteration 397: HV = 113.18, HVR = 0.88
# Iteration 398: HV = 113.07, HVR = 0.88
# Iteration 399: HV = 113.17, HVR = 0.88
# Iteration 400: HV = 113.12, HVR = 0.88
# Iteration 401: HV = 113.11, HVR = 0.88
# Iteration 402: HV = 113.13, HVR = 0.88
# Iteration 403: HV = 113.14, HVR = 0.88
# Iteration 404: HV = 113.14, HVR = 0.88
# Iteration 405: HV = 113.16, HVR = 0.88
# Iteration 406: HV = 113.07, HVR = 0.88
# Iteration 407: HV = 112.94, HVR = 0.88
# Iteration 408: HV = 112.87, HVR = 0.88
# Iteration 409: HV = 112.94, HVR = 0.88
# Iteration 410: HV = 112.95, HVR = 0.88
# Iteration 411: HV = 112.94, HVR = 0.88
# Iteration 412: HV = 113.11, HVR = 0.88
# Iteration 413: HV = 113.00, HVR = 0.88
# Iteration 414: HV = 113.02, HVR = 0.88
# Iteration 415: HV = 113.01, HVR = 0.88
# Iteration 416: HV = 112.99, HVR = 0.88
# Iteration 417: HV = 112.93, HVR = 0.88
# Iteration 418: HV = 112.96, HVR = 0.88
# Iteration 419: HV = 113.06, HVR = 0.88
# Iteration 420: HV = 112.99, HVR = 0.88
# Iteration 421: HV = 112.98, HVR = 0.88
# Iteration 422: HV = 112.94, HVR = 0.88
# Iteration 423: HV = 112.97, HVR = 0.88
# Iteration 424: HV = 113.01, HVR = 0.88
# Iteration 425: HV = 112.93, HVR = 0.88
# Iteration 426: HV = 113.03, HVR = 0.88
# Iteration 427: HV = 112.98, HVR = 0.88
# Iteration 428: HV = 113.03, HVR = 0.88
# Iteration 429: HV = 112.94, HVR = 0.88
# Iteration 430: HV = 112.97, HVR = 0.88
# Iteration 431: HV = 112.83, HVR = 0.88
# Iteration 432: HV = 112.88, HVR = 0.88
# Iteration 433: HV = 112.84, HVR = 0.88
# Iteration 434: HV = 112.76, HVR = 0.88
# Iteration 435: HV = 112.73, HVR = 0.88
# Iteration 436: HV = 112.69, HVR = 0.88
# Iteration 437: HV = 112.69, HVR = 0.88
# Iteration 438: HV = 112.68, HVR = 0.87
# Iteration 439: HV = 112.58, HVR = 0.87
# Iteration 440: HV = 112.65, HVR = 0.87
# Iteration 441: HV = 112.79, HVR = 0.88
# Iteration 442: HV = 112.84, HVR = 0.88
# Iteration 443: HV = 112.66, HVR = 0.87
# Iteration 444: HV = 112.74, HVR = 0.88
# Iteration 445: HV = 112.67, HVR = 0.87
# Iteration 446: HV = 112.67, HVR = 0.87
# Iteration 447: HV = 112.69, HVR = 0.88
# Iteration 448: HV = 112.58, HVR = 0.87
# Iteration 449: HV = 112.69, HVR = 0.88
# Iteration 450: HV = 112.58, HVR = 0.87
# Iteration 451: HV = 112.73, HVR = 0.88
# Iteration 452: HV = 112.72, HVR = 0.88
# Iteration 453: HV = 112.73, HVR = 0.88
# Iteration 454: HV = 112.76, HVR = 0.88
# Iteration 455: HV = 112.64, HVR = 0.87
# Iteration 456: HV = 112.65, HVR = 0.87
# Iteration 457: HV = 112.59, HVR = 0.87
# Iteration 458: HV = 112.41, HVR = 0.87
# Iteration 459: HV = 112.49, HVR = 0.87
# Iteration 460: HV = 112.45, HVR = 0.87
# Iteration 461: HV = 112.62, HVR = 0.87
# Iteration 462: HV = 112.47, HVR = 0.87
# Iteration 463: HV = 112.40, HVR = 0.87
# Iteration 464: HV = 112.56, HVR = 0.87
# Iteration 465: HV = 112.46, HVR = 0.87
# Iteration 466: HV = 112.45, HVR = 0.87
# Iteration 467: HV = 112.45, HVR = 0.87
# Iteration 468: HV = 112.45, HVR = 0.87
# Iteration 469: HV = 112.45, HVR = 0.87
# Iteration 470: HV = 112.42, HVR = 0.87
# Iteration 471: HV = 112.41, HVR = 0.87
# Iteration 472: HV = 112.44, HVR = 0.87
# Iteration 473: HV = 112.40, HVR = 0.87
# Iteration 474: HV = 112.33, HVR = 0.87
# Iteration 475: HV = 112.50, HVR = 0.87
# Iteration 476: HV = 112.54, HVR = 0.87
# Iteration 477: HV = 112.54, HVR = 0.87
# Iteration 478: HV = 112.42, HVR = 0.87
# Iteration 479: HV = 112.41, HVR = 0.87
# Iteration 480: HV = 112.40, HVR = 0.87
# Iteration 481: HV = 112.36, HVR = 0.87
# Iteration 482: HV = 112.40, HVR = 0.87
# Iteration 483: HV = 112.33, HVR = 0.87
# Iteration 484: HV = 112.38, HVR = 0.87
# Iteration 485: HV = 112.31, HVR = 0.87
# Iteration 486: HV = 112.35, HVR = 0.87
# Iteration 487: HV = 112.58, HVR = 0.87
# Iteration 488: HV = 112.52, HVR = 0.87
# Iteration 489: HV = 112.49, HVR = 0.87
# Iteration 490: HV = 112.52, HVR = 0.87
# Iteration 491: HV = 112.60, HVR = 0.87
# Iteration 492: HV = 112.46, HVR = 0.87
# Iteration 493: HV = 112.52, HVR = 0.87
# Iteration 494: HV = 112.40, HVR = 0.87
# Iteration 495: HV = 112.37, HVR = 0.87
# Iteration 496: HV = 112.47, HVR = 0.87
# Iteration 497: HV = 112.30, HVR = 0.87
# Iteration 498: HV = 112.20, HVR = 0.87
# Iteration 499: HV = 112.33, HVR = 0.87
# CPU times: user 1min 15s, sys: 8.27 s, total: 1min 23s
# Wall time: 1min 10s

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
