# %% [markdown]
# # Optymalizacja wielokryterialna
#
# Notebook pokazuje przykład działania algorytmu NSGA-II na benchmarku ZDT3.
#
# Literatura dodatkowa:
#
# [1] E. Zitzler, K. Deb, L. Thiele, Comparison of Multiobjective Evolutionary Algorithms: Empirical Results, Evolutionary Computation, vol 8, no 2, 2000, pp. 173-195. [http://www.tik.ee.ethz.ch/sop/publicationListFiles/zdt2000a.pdf]
#
# [2] Multi-objective Benchmark Problems. [http://www.tik.ee.ethz.ch/sop/download/supplementary/testproblems/]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Działanie NSGA-II na ZDT3

# %% [markdown]
# ### Problem ZDT3
#
# Problem ZDT3 to dość popularny problem testowy dla optymalizacji wielokryterialnej.
#
# Przestrzeń poszukiwań: $\Omega = [0, 1]^d$.
#
# Dwa kryteria (oba minimalizujemy):
#
# $$f_1(\mathbf{x}) = x_1,$$
#
# $$f_2(\mathbf{x}) = g(\mathbf{x}) [1 - \sqrt{x_1 / g(\mathbf{x})} - x_1 / g(\mathbf{x}) \sin(10 \pi x_1)],$$
# gdzie $g(\mathbf{x}) = 1 + \frac{9}{d-1}\sum_{i=2}^d x_i$.

# %% [markdown]
# ### Dokładny front Pareto dla ZDT3
#
# Znane są wzory na dokładny front Pareto dla ZDT3 (patrz [1] lub [2]).

# %%
F = np.array([[0.0000000000, 0.0830015349],
              [0.1822287280, 0.2577623634],
              [0.4093136748, 0.4538821041],
              [0.6183967944, 0.6525117038],
              [0.8233317983, 0.8518328654]])

r = 10
X = (np.tile(np.linspace(0, 1, r), [F.shape[0], 1]) * (F[:, 1] - F[:, 0])[np.newaxis].T + F[:, 0][np.newaxis].T)
Y = 1 - np.sqrt(X) - X * np.sin(10 * np.pi * X)

plt.figure(figsize=(12, 8))
for i in xrange(F.shape[0]):
    plt.plot(X[i, :].ravel(), Y[i, :].ravel(), 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT3Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt3_definitions import ZDT3Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT3Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = []
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT3Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics.append((hv, hvr, ranks, crowding_distances, objectives))

# %%
def plot_PF(results):
    PF = np.array([i.objectives for i in results])

    plt.figure(figsize=(12, 8))
    plt.plot(PF[:, 0], PF[:, 1], 'ro')
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.title('Pareto Front')
    plt.show()

# %%
# %%time

solver = Evolution(ZDT(ZDT3Definitions()), 250, 100)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()

plot_PF(results)
# Out:
# Iteration 000: HV = 79.58, HVR = 0.62
# Iteration 001: HV = 82.08, HVR = 0.64
# Iteration 002: HV = 82.57, HVR = 0.64
# Iteration 003: HV = 83.27, HVR = 0.65
# Iteration 004: HV = 83.85, HVR = 0.65
# Iteration 005: HV = 84.23, HVR = 0.65
# Iteration 006: HV = 86.16, HVR = 0.67
# Iteration 007: HV = 88.27, HVR = 0.69
# Iteration 008: HV = 89.57, HVR = 0.70
# Iteration 009: HV = 90.27, HVR = 0.70
# Iteration 010: HV = 90.53, HVR = 0.70
# Iteration 011: HV = 91.77, HVR = 0.71
# Iteration 012: HV = 92.10, HVR = 0.72
# Iteration 013: HV = 93.61, HVR = 0.73
# Iteration 014: HV = 93.15, HVR = 0.72
# Iteration 015: HV = 94.39, HVR = 0.73
# Iteration 016: HV = 93.96, HVR = 0.73
# Iteration 017: HV = 94.95, HVR = 0.74
# Iteration 018: HV = 95.90, HVR = 0.74
# Iteration 019: HV = 97.30, HVR = 0.76
# Iteration 020: HV = 97.84, HVR = 0.76
# Iteration 021: HV = 99.45, HVR = 0.77
# Iteration 022: HV = 99.70, HVR = 0.77
# Iteration 023: HV = 100.40, HVR = 0.78
# Iteration 024: HV = 100.69, HVR = 0.78
# Iteration 025: HV = 100.40, HVR = 0.78
# Iteration 026: HV = 101.22, HVR = 0.79
# Iteration 027: HV = 101.50, HVR = 0.79
# Iteration 028: HV = 102.70, HVR = 0.80
# Iteration 029: HV = 102.99, HVR = 0.80
# Iteration 030: HV = 104.66, HVR = 0.81
# Iteration 031: HV = 105.33, HVR = 0.82
# Iteration 032: HV = 104.92, HVR = 0.81
# Iteration 033: HV = 105.34, HVR = 0.82
# Iteration 034: HV = 105.27, HVR = 0.82
# Iteration 035: HV = 105.58, HVR = 0.82
# Iteration 036: HV = 105.81, HVR = 0.82
# Iteration 037: HV = 106.18, HVR = 0.82
# Iteration 038: HV = 106.54, HVR = 0.83
# Iteration 039: HV = 107.07, HVR = 0.83
# Iteration 040: HV = 107.45, HVR = 0.83
# Iteration 041: HV = 107.50, HVR = 0.83
# Iteration 042: HV = 108.34, HVR = 0.84
# Iteration 043: HV = 108.51, HVR = 0.84
# Iteration 044: HV = 108.26, HVR = 0.84
# Iteration 045: HV = 108.35, HVR = 0.84
# Iteration 046: HV = 108.93, HVR = 0.85
# Iteration 047: HV = 108.89, HVR = 0.85
# Iteration 048: HV = 109.56, HVR = 0.85
# Iteration 049: HV = 110.03, HVR = 0.85
# Iteration 050: HV = 110.18, HVR = 0.86
# Iteration 051: HV = 110.28, HVR = 0.86
# Iteration 052: HV = 110.30, HVR = 0.86
# Iteration 053: HV = 110.29, HVR = 0.86
# Iteration 054: HV = 110.81, HVR = 0.86
# Iteration 055: HV = 111.24, HVR = 0.86
# Iteration 056: HV = 111.51, HVR = 0.87
# Iteration 057: HV = 111.70, HVR = 0.87
# Iteration 058: HV = 111.62, HVR = 0.87
# Iteration 059: HV = 112.20, HVR = 0.87
# Iteration 060: HV = 112.41, HVR = 0.87
# Iteration 061: HV = 112.11, HVR = 0.87
# Iteration 062: HV = 112.41, HVR = 0.87
# Iteration 063: HV = 112.65, HVR = 0.87
# Iteration 064: HV = 112.93, HVR = 0.88
# Iteration 065: HV = 112.77, HVR = 0.88
# Iteration 066: HV = 112.72, HVR = 0.88
# Iteration 067: HV = 112.93, HVR = 0.88
# Iteration 068: HV = 113.11, HVR = 0.88
# Iteration 069: HV = 113.31, HVR = 0.88
# Iteration 070: HV = 113.31, HVR = 0.88
# Iteration 071: HV = 113.12, HVR = 0.88
# Iteration 072: HV = 113.10, HVR = 0.88
# Iteration 073: HV = 113.10, HVR = 0.88
# Iteration 074: HV = 113.28, HVR = 0.88
# Iteration 075: HV = 113.42, HVR = 0.88
# Iteration 076: HV = 113.20, HVR = 0.88
# Iteration 077: HV = 113.07, HVR = 0.88
# Iteration 078: HV = 113.13, HVR = 0.88
# Iteration 079: HV = 113.42, HVR = 0.88
# Iteration 080: HV = 113.54, HVR = 0.88
# Iteration 081: HV = 113.63, HVR = 0.88
# Iteration 082: HV = 113.65, HVR = 0.88
# Iteration 083: HV = 113.48, HVR = 0.88
# Iteration 084: HV = 113.44, HVR = 0.88
# Iteration 085: HV = 113.58, HVR = 0.88
# Iteration 086: HV = 113.44, HVR = 0.88
# Iteration 087: HV = 113.65, HVR = 0.88
# Iteration 088: HV = 113.78, HVR = 0.88
# Iteration 089: HV = 113.82, HVR = 0.88
# Iteration 090: HV = 113.85, HVR = 0.88
# Iteration 091: HV = 113.77, HVR = 0.88
# Iteration 092: HV = 113.83, HVR = 0.88
# Iteration 093: HV = 113.99, HVR = 0.89
# Iteration 094: HV = 114.09, HVR = 0.89
# Iteration 095: HV = 114.11, HVR = 0.89
# Iteration 096: HV = 114.07, HVR = 0.89
# Iteration 097: HV = 114.15, HVR = 0.89
# Iteration 098: HV = 113.99, HVR = 0.89
# Iteration 099: HV = 113.88, HVR = 0.88
# Iteration 100: HV = 113.90, HVR = 0.88
# Iteration 101: HV = 113.91, HVR = 0.88
# Iteration 102: HV = 114.08, HVR = 0.89
# Iteration 103: HV = 114.09, HVR = 0.89
# Iteration 104: HV = 114.16, HVR = 0.89
# Iteration 105: HV = 114.14, HVR = 0.89
# Iteration 106: HV = 114.18, HVR = 0.89
# Iteration 107: HV = 114.23, HVR = 0.89
# Iteration 108: HV = 114.12, HVR = 0.89
# Iteration 109: HV = 114.14, HVR = 0.89
# Iteration 110: HV = 114.27, HVR = 0.89
# Iteration 111: HV = 114.19, HVR = 0.89
# Iteration 112: HV = 114.31, HVR = 0.89
# Iteration 113: HV = 114.29, HVR = 0.89
# Iteration 114: HV = 114.25, HVR = 0.89
# Iteration 115: HV = 114.27, HVR = 0.89
# Iteration 116: HV = 114.21, HVR = 0.89
# Iteration 117: HV = 114.26, HVR = 0.89
# Iteration 118: HV = 114.15, HVR = 0.89
# Iteration 119: HV = 114.17, HVR = 0.89
# Iteration 120: HV = 114.22, HVR = 0.89
# Iteration 121: HV = 114.34, HVR = 0.89
# Iteration 122: HV = 114.35, HVR = 0.89
# Iteration 123: HV = 114.29, HVR = 0.89
# Iteration 124: HV = 114.22, HVR = 0.89
# Iteration 125: HV = 114.21, HVR = 0.89
# Iteration 126: HV = 114.30, HVR = 0.89
# Iteration 127: HV = 114.18, HVR = 0.89
# Iteration 128: HV = 114.17, HVR = 0.89
# Iteration 129: HV = 114.22, HVR = 0.89
# Iteration 130: HV = 114.19, HVR = 0.89
# Iteration 131: HV = 114.11, HVR = 0.89
# Iteration 132: HV = 114.25, HVR = 0.89
# Iteration 133: HV = 114.30, HVR = 0.89
# Iteration 134: HV = 114.21, HVR = 0.89
# Iteration 135: HV = 114.18, HVR = 0.89
# Iteration 136: HV = 114.17, HVR = 0.89
# Iteration 137: HV = 114.17, HVR = 0.89
# Iteration 138: HV = 114.16, HVR = 0.89
# Iteration 139: HV = 114.22, HVR = 0.89
# Iteration 140: HV = 114.21, HVR = 0.89
# Iteration 141: HV = 114.28, HVR = 0.89
# Iteration 142: HV = 114.29, HVR = 0.89
# Iteration 143: HV = 114.30, HVR = 0.89
# Iteration 144: HV = 114.37, HVR = 0.89
# Iteration 145: HV = 114.47, HVR = 0.89
# Iteration 146: HV = 114.45, HVR = 0.89
# Iteration 147: HV = 114.45, HVR = 0.89
# Iteration 148: HV = 114.54, HVR = 0.89
# Iteration 149: HV = 114.47, HVR = 0.89
# Iteration 150: HV = 114.46, HVR = 0.89
# Iteration 151: HV = 114.35, HVR = 0.89
# Iteration 152: HV = 114.36, HVR = 0.89
# Iteration 153: HV = 114.28, HVR = 0.89
# Iteration 154: HV = 114.26, HVR = 0.89
# Iteration 155: HV = 114.34, HVR = 0.89
# Iteration 156: HV = 114.41, HVR = 0.89
# Iteration 157: HV = 114.54, HVR = 0.89
# Iteration 158: HV = 114.51, HVR = 0.89
# Iteration 159: HV = 114.55, HVR = 0.89
# Iteration 160: HV = 114.50, HVR = 0.89
# Iteration 161: HV = 114.53, HVR = 0.89
# Iteration 162: HV = 114.53, HVR = 0.89
# Iteration 163: HV = 114.54, HVR = 0.89
# Iteration 164: HV = 114.57, HVR = 0.89
# Iteration 165: HV = 114.55, HVR = 0.89
# Iteration 166: HV = 114.58, HVR = 0.89
# Iteration 167: HV = 114.60, HVR = 0.89
# Iteration 168: HV = 114.65, HVR = 0.89
# Iteration 169: HV = 114.67, HVR = 0.89
# Iteration 170: HV = 114.67, HVR = 0.89
# Iteration 171: HV = 114.66, HVR = 0.89
# Iteration 172: HV = 114.62, HVR = 0.89
# Iteration 173: HV = 114.52, HVR = 0.89
# Iteration 174: HV = 114.60, HVR = 0.89
# Iteration 175: HV = 114.58, HVR = 0.89
# Iteration 176: HV = 114.55, HVR = 0.89
# Iteration 177: HV = 114.49, HVR = 0.89
# Iteration 178: HV = 114.54, HVR = 0.89
# Iteration 179: HV = 114.52, HVR = 0.89
# Iteration 180: HV = 114.53, HVR = 0.89
# Iteration 181: HV = 114.41, HVR = 0.89
# Iteration 182: HV = 114.38, HVR = 0.89
# Iteration 183: HV = 114.37, HVR = 0.89
# Iteration 184: HV = 114.41, HVR = 0.89
# Iteration 185: HV = 114.40, HVR = 0.89
# Iteration 186: HV = 114.25, HVR = 0.89
# Iteration 187: HV = 114.26, HVR = 0.89
# Iteration 188: HV = 114.26, HVR = 0.89
# Iteration 189: HV = 114.30, HVR = 0.89
# Iteration 190: HV = 114.30, HVR = 0.89
# Iteration 191: HV = 114.23, HVR = 0.89
# Iteration 192: HV = 114.30, HVR = 0.89
# Iteration 193: HV = 114.38, HVR = 0.89
# Iteration 194: HV = 114.35, HVR = 0.89
# Iteration 195: HV = 114.29, HVR = 0.89
# Iteration 196: HV = 114.28, HVR = 0.89
# Iteration 197: HV = 114.32, HVR = 0.89
# Iteration 198: HV = 114.24, HVR = 0.89
# Iteration 199: HV = 114.27, HVR = 0.89
# Iteration 200: HV = 114.20, HVR = 0.89
# Iteration 201: HV = 114.18, HVR = 0.89
# Iteration 202: HV = 114.11, HVR = 0.89
# Iteration 203: HV = 114.14, HVR = 0.89
# Iteration 204: HV = 114.08, HVR = 0.89
# Iteration 205: HV = 114.07, HVR = 0.89
# Iteration 206: HV = 113.96, HVR = 0.88
# Iteration 207: HV = 113.98, HVR = 0.89
# Iteration 208: HV = 113.98, HVR = 0.89
# Iteration 209: HV = 114.00, HVR = 0.89
# Iteration 210: HV = 113.99, HVR = 0.89
# Iteration 211: HV = 113.97, HVR = 0.89
# Iteration 212: HV = 113.96, HVR = 0.88
# Iteration 213: HV = 113.92, HVR = 0.88
# Iteration 214: HV = 113.88, HVR = 0.88
# Iteration 215: HV = 113.98, HVR = 0.89
# Iteration 216: HV = 113.97, HVR = 0.88
# Iteration 217: HV = 113.95, HVR = 0.88
# Iteration 218: HV = 113.89, HVR = 0.88
# Iteration 219: HV = 113.95, HVR = 0.88
# Iteration 220: HV = 114.07, HVR = 0.89
# Iteration 221: HV = 114.12, HVR = 0.89
# Iteration 222: HV = 114.10, HVR = 0.89
# Iteration 223: HV = 114.06, HVR = 0.89
# Iteration 224: HV = 114.03, HVR = 0.89
# Iteration 225: HV = 114.06, HVR = 0.89
# Iteration 226: HV = 113.99, HVR = 0.89
# Iteration 227: HV = 113.98, HVR = 0.89
# Iteration 228: HV = 114.06, HVR = 0.89
# Iteration 229: HV = 113.97, HVR = 0.88
# Iteration 230: HV = 114.04, HVR = 0.89
# Iteration 231: HV = 114.05, HVR = 0.89
# Iteration 232: HV = 114.09, HVR = 0.89
# Iteration 233: HV = 114.12, HVR = 0.89
# Iteration 234: HV = 114.09, HVR = 0.89
# Iteration 235: HV = 114.09, HVR = 0.89
# Iteration 236: HV = 114.07, HVR = 0.89
# Iteration 237: HV = 114.03, HVR = 0.89
# Iteration 238: HV = 114.05, HVR = 0.89
# Iteration 239: HV = 114.12, HVR = 0.89
# Iteration 240: HV = 114.07, HVR = 0.89
# Iteration 241: HV = 114.03, HVR = 0.89
# Iteration 242: HV = 114.09, HVR = 0.89
# Iteration 243: HV = 114.06, HVR = 0.89
# Iteration 244: HV = 114.15, HVR = 0.89
# Iteration 245: HV = 114.07, HVR = 0.89
# Iteration 246: HV = 114.01, HVR = 0.89
# Iteration 247: HV = 114.08, HVR = 0.89
# Iteration 248: HV = 114.00, HVR = 0.89
# Iteration 249: HV = 114.06, HVR = 0.89
# CPU times: user 2min 12s, sys: 11 s, total: 2min 23s
# Wall time: 2min 3s

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
