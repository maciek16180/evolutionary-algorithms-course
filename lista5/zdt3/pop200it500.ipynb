# %% [markdown]
# # Optymalizacja wielokryterialna
#
# Notebook pokazuje przykład działania algorytmu NSGA-II na benchmarku ZDT3.
#
# Literatura dodatkowa:
#
# [1] E. Zitzler, K. Deb, L. Thiele, Comparison of Multiobjective Evolutionary Algorithms: Empirical Results, Evolutionary Computation, vol 8, no 2, 2000, pp. 173-195. [http://www.tik.ee.ethz.ch/sop/publicationListFiles/zdt2000a.pdf]
#
# [2] Multi-objective Benchmark Problems. [http://www.tik.ee.ethz.ch/sop/download/supplementary/testproblems/]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Działanie NSGA-II na ZDT3

# %% [markdown]
# ### Problem ZDT3
#
# Problem ZDT3 to dość popularny problem testowy dla optymalizacji wielokryterialnej.
#
# Przestrzeń poszukiwań: $\Omega = [0, 1]^d$.
#
# Dwa kryteria (oba minimalizujemy):
#
# $$f_1(\mathbf{x}) = x_1,$$
#
# $$f_2(\mathbf{x}) = g(\mathbf{x}) [1 - \sqrt{x_1 / g(\mathbf{x})} - x_1 / g(\mathbf{x}) \sin(10 \pi x_1)],$$
# gdzie $g(\mathbf{x}) = 1 + \frac{9}{d-1}\sum_{i=2}^d x_i$.

# %% [markdown]
# ### Dokładny front Pareto dla ZDT3
#
# Znane są wzory na dokładny front Pareto dla ZDT3 (patrz [1] lub [2]).

# %%
F = np.array([[0.0000000000, 0.0830015349],
              [0.1822287280, 0.2577623634],
              [0.4093136748, 0.4538821041],
              [0.6183967944, 0.6525117038],
              [0.8233317983, 0.8518328654]])

r = 10
X = (np.tile(np.linspace(0, 1, r), [F.shape[0], 1]) * (F[:, 1] - F[:, 0])[np.newaxis].T + F[:, 0][np.newaxis].T)
Y = 1 - np.sqrt(X) - X * np.sin(10 * np.pi * X)

plt.figure(figsize=(12, 8))
for i in xrange(F.shape[0]):
    plt.plot(X[i, :].ravel(), Y[i, :].ravel(), 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT3Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt3_definitions import ZDT3Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT3Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = []
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT3Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics.append((hv, hvr, ranks, crowding_distances, objectives))

# %%
def plot_PF(results):
    PF = np.array([i.objectives for i in results])

    plt.figure(figsize=(12, 8))
    plt.plot(PF[:, 0], PF[:, 1], 'ro')
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.title('Pareto Front')
    plt.show()

# %%
# %%time

solver = Evolution(ZDT(ZDT3Definitions()), 500, 200)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()

plot_PF(results)
# Out:
# Iteration 000: HV = 78.71, HVR = 0.61
# Iteration 001: HV = 82.66, HVR = 0.64
# Iteration 002: HV = 84.43, HVR = 0.66
# Iteration 003: HV = 85.95, HVR = 0.67
# Iteration 004: HV = 85.62, HVR = 0.66
# Iteration 005: HV = 85.71, HVR = 0.67
# Iteration 006: HV = 86.86, HVR = 0.67
# Iteration 007: HV = 88.83, HVR = 0.69
# Iteration 008: HV = 91.39, HVR = 0.71
# Iteration 009: HV = 91.58, HVR = 0.71
# Iteration 010: HV = 91.21, HVR = 0.71
# Iteration 011: HV = 91.93, HVR = 0.71
# Iteration 012: HV = 93.40, HVR = 0.73
# Iteration 013: HV = 94.63, HVR = 0.73
# Iteration 014: HV = 94.95, HVR = 0.74
# Iteration 015: HV = 95.51, HVR = 0.74
# Iteration 016: HV = 96.04, HVR = 0.75
# Iteration 017: HV = 96.83, HVR = 0.75
# Iteration 018: HV = 98.36, HVR = 0.76
# Iteration 019: HV = 98.47, HVR = 0.76
# Iteration 020: HV = 98.41, HVR = 0.76
# Iteration 021: HV = 99.20, HVR = 0.77
# Iteration 022: HV = 98.97, HVR = 0.77
# Iteration 023: HV = 99.76, HVR = 0.77
# Iteration 024: HV = 101.85, HVR = 0.79
# Iteration 025: HV = 102.41, HVR = 0.80
# Iteration 026: HV = 102.00, HVR = 0.79
# Iteration 027: HV = 103.66, HVR = 0.80
# Iteration 028: HV = 103.64, HVR = 0.80
# Iteration 029: HV = 104.23, HVR = 0.81
# Iteration 030: HV = 104.80, HVR = 0.81
# Iteration 031: HV = 105.31, HVR = 0.82
# Iteration 032: HV = 105.15, HVR = 0.82
# Iteration 033: HV = 106.88, HVR = 0.83
# Iteration 034: HV = 107.02, HVR = 0.83
# Iteration 035: HV = 107.34, HVR = 0.83
# Iteration 036: HV = 108.56, HVR = 0.84
# Iteration 037: HV = 108.92, HVR = 0.85
# Iteration 038: HV = 109.52, HVR = 0.85
# Iteration 039: HV = 109.07, HVR = 0.85
# Iteration 040: HV = 109.37, HVR = 0.85
# Iteration 041: HV = 110.08, HVR = 0.85
# Iteration 042: HV = 110.49, HVR = 0.86
# Iteration 043: HV = 110.72, HVR = 0.86
# Iteration 044: HV = 110.52, HVR = 0.86
# Iteration 045: HV = 110.92, HVR = 0.86
# Iteration 046: HV = 111.67, HVR = 0.87
# Iteration 047: HV = 111.74, HVR = 0.87
# Iteration 048: HV = 111.45, HVR = 0.87
# Iteration 049: HV = 111.74, HVR = 0.87
# Iteration 050: HV = 111.87, HVR = 0.87
# Iteration 051: HV = 111.99, HVR = 0.87
# Iteration 052: HV = 112.23, HVR = 0.87
# Iteration 053: HV = 112.33, HVR = 0.87
# Iteration 054: HV = 112.48, HVR = 0.87
# Iteration 055: HV = 112.77, HVR = 0.88
# Iteration 056: HV = 112.72, HVR = 0.88
# Iteration 057: HV = 112.95, HVR = 0.88
# Iteration 058: HV = 113.01, HVR = 0.88
# Iteration 059: HV = 113.25, HVR = 0.88
# Iteration 060: HV = 112.97, HVR = 0.88
# Iteration 061: HV = 113.35, HVR = 0.88
# Iteration 062: HV = 112.89, HVR = 0.88
# Iteration 063: HV = 113.20, HVR = 0.88
# Iteration 064: HV = 113.43, HVR = 0.88
# Iteration 065: HV = 113.50, HVR = 0.88
# Iteration 066: HV = 113.90, HVR = 0.88
# Iteration 067: HV = 113.70, HVR = 0.88
# Iteration 068: HV = 113.64, HVR = 0.88
# Iteration 069: HV = 113.82, HVR = 0.88
# Iteration 070: HV = 114.01, HVR = 0.89
# Iteration 071: HV = 114.00, HVR = 0.89
# Iteration 072: HV = 114.18, HVR = 0.89
# Iteration 073: HV = 114.22, HVR = 0.89
# Iteration 074: HV = 114.14, HVR = 0.89
# Iteration 075: HV = 114.30, HVR = 0.89
# Iteration 076: HV = 114.31, HVR = 0.89
# Iteration 077: HV = 114.33, HVR = 0.89
# Iteration 078: HV = 114.26, HVR = 0.89
# Iteration 079: HV = 114.24, HVR = 0.89
# Iteration 080: HV = 114.31, HVR = 0.89
# Iteration 081: HV = 114.17, HVR = 0.89
# Iteration 082: HV = 114.09, HVR = 0.89
# Iteration 083: HV = 114.10, HVR = 0.89
# Iteration 084: HV = 114.18, HVR = 0.89
# Iteration 085: HV = 114.09, HVR = 0.89
# Iteration 086: HV = 113.91, HVR = 0.88
# Iteration 087: HV = 114.01, HVR = 0.89
# Iteration 088: HV = 114.15, HVR = 0.89
# Iteration 089: HV = 114.21, HVR = 0.89
# Iteration 090: HV = 114.06, HVR = 0.89
# Iteration 091: HV = 114.05, HVR = 0.89
# Iteration 092: HV = 114.02, HVR = 0.89
# Iteration 093: HV = 114.24, HVR = 0.89
# Iteration 094: HV = 114.27, HVR = 0.89
# Iteration 095: HV = 114.21, HVR = 0.89
# Iteration 096: HV = 114.26, HVR = 0.89
# Iteration 097: HV = 114.20, HVR = 0.89
# Iteration 098: HV = 114.23, HVR = 0.89
# Iteration 099: HV = 114.31, HVR = 0.89
# Iteration 100: HV = 114.17, HVR = 0.89
# Iteration 101: HV = 114.22, HVR = 0.89
# Iteration 102: HV = 114.29, HVR = 0.89
# Iteration 103: HV = 114.43, HVR = 0.89
# Iteration 104: HV = 114.45, HVR = 0.89
# Iteration 105: HV = 114.53, HVR = 0.89
# Iteration 106: HV = 114.41, HVR = 0.89
# Iteration 107: HV = 114.55, HVR = 0.89
# Iteration 108: HV = 114.60, HVR = 0.89
# Iteration 109: HV = 114.49, HVR = 0.89
# Iteration 110: HV = 114.58, HVR = 0.89
# Iteration 111: HV = 114.65, HVR = 0.89
# Iteration 112: HV = 114.66, HVR = 0.89
# Iteration 113: HV = 114.66, HVR = 0.89
# Iteration 114: HV = 114.63, HVR = 0.89
# Iteration 115: HV = 114.61, HVR = 0.89
# Iteration 116: HV = 114.59, HVR = 0.89
# Iteration 117: HV = 114.53, HVR = 0.89
# Iteration 118: HV = 114.53, HVR = 0.89
# Iteration 119: HV = 114.55, HVR = 0.89
# Iteration 120: HV = 114.67, HVR = 0.89
# Iteration 121: HV = 114.57, HVR = 0.89
# Iteration 122: HV = 114.59, HVR = 0.89
# Iteration 123: HV = 114.60, HVR = 0.89
# Iteration 124: HV = 114.62, HVR = 0.89
# Iteration 125: HV = 114.60, HVR = 0.89
# Iteration 126: HV = 114.56, HVR = 0.89
# Iteration 127: HV = 114.63, HVR = 0.89
# Iteration 128: HV = 114.57, HVR = 0.89
# Iteration 129: HV = 114.63, HVR = 0.89
# Iteration 130: HV = 114.70, HVR = 0.89
# Iteration 131: HV = 114.79, HVR = 0.89
# Iteration 132: HV = 114.83, HVR = 0.89
# Iteration 133: HV = 114.82, HVR = 0.89
# Iteration 134: HV = 114.81, HVR = 0.89
# Iteration 135: HV = 114.84, HVR = 0.89
# Iteration 136: HV = 114.90, HVR = 0.89
# Iteration 137: HV = 114.93, HVR = 0.89
# Iteration 138: HV = 114.91, HVR = 0.89
# Iteration 139: HV = 114.75, HVR = 0.89
# Iteration 140: HV = 114.76, HVR = 0.89
# Iteration 141: HV = 114.79, HVR = 0.89
# Iteration 142: HV = 114.84, HVR = 0.89
# Iteration 143: HV = 114.88, HVR = 0.89
# Iteration 144: HV = 114.83, HVR = 0.89
# Iteration 145: HV = 114.86, HVR = 0.89
# Iteration 146: HV = 114.79, HVR = 0.89
# Iteration 147: HV = 114.75, HVR = 0.89
# Iteration 148: HV = 114.79, HVR = 0.89
# Iteration 149: HV = 114.76, HVR = 0.89
# Iteration 150: HV = 114.85, HVR = 0.89
# Iteration 151: HV = 114.83, HVR = 0.89
# Iteration 152: HV = 114.91, HVR = 0.89
# Iteration 153: HV = 114.91, HVR = 0.89
# Iteration 154: HV = 114.86, HVR = 0.89
# Iteration 155: HV = 114.88, HVR = 0.89
# Iteration 156: HV = 114.91, HVR = 0.89
# Iteration 157: HV = 114.90, HVR = 0.89
# Iteration 158: HV = 114.87, HVR = 0.89
# Iteration 159: HV = 114.89, HVR = 0.89
# Iteration 160: HV = 114.84, HVR = 0.89
# Iteration 161: HV = 114.81, HVR = 0.89
# Iteration 162: HV = 114.89, HVR = 0.89
# Iteration 163: HV = 114.84, HVR = 0.89
# Iteration 164: HV = 114.81, HVR = 0.89
# Iteration 165: HV = 114.80, HVR = 0.89
# Iteration 166: HV = 114.79, HVR = 0.89
# Iteration 167: HV = 114.72, HVR = 0.89
# Iteration 168: HV = 114.75, HVR = 0.89
# Iteration 169: HV = 114.76, HVR = 0.89
# Iteration 170: HV = 114.76, HVR = 0.89
# Iteration 171: HV = 114.76, HVR = 0.89
# Iteration 172: HV = 114.79, HVR = 0.89
# Iteration 173: HV = 114.80, HVR = 0.89
# Iteration 174: HV = 114.79, HVR = 0.89
# Iteration 175: HV = 114.78, HVR = 0.89
# Iteration 176: HV = 114.80, HVR = 0.89
# Iteration 177: HV = 114.81, HVR = 0.89
# Iteration 178: HV = 114.82, HVR = 0.89
# Iteration 179: HV = 114.77, HVR = 0.89
# Iteration 180: HV = 114.73, HVR = 0.89
# Iteration 181: HV = 114.65, HVR = 0.89
# Iteration 182: HV = 114.65, HVR = 0.89
# Iteration 183: HV = 114.65, HVR = 0.89
# Iteration 184: HV = 114.79, HVR = 0.89
# Iteration 185: HV = 114.85, HVR = 0.89
# Iteration 186: HV = 114.83, HVR = 0.89
# Iteration 187: HV = 114.83, HVR = 0.89
# Iteration 188: HV = 114.82, HVR = 0.89
# Iteration 189: HV = 114.80, HVR = 0.89
# Iteration 190: HV = 114.80, HVR = 0.89
# Iteration 191: HV = 114.82, HVR = 0.89
# Iteration 192: HV = 114.81, HVR = 0.89
# Iteration 193: HV = 114.80, HVR = 0.89
# Iteration 194: HV = 114.80, HVR = 0.89
# Iteration 195: HV = 114.79, HVR = 0.89
# Iteration 196: HV = 114.73, HVR = 0.89
# Iteration 197: HV = 114.72, HVR = 0.89
# Iteration 198: HV = 114.71, HVR = 0.89
# Iteration 199: HV = 114.68, HVR = 0.89
# Iteration 200: HV = 114.62, HVR = 0.89
# Iteration 201: HV = 114.60, HVR = 0.89
# Iteration 202: HV = 114.58, HVR = 0.89
# Iteration 203: HV = 114.58, HVR = 0.89
# Iteration 204: HV = 114.55, HVR = 0.89
# Iteration 205: HV = 114.61, HVR = 0.89
# Iteration 206: HV = 114.61, HVR = 0.89
# Iteration 207: HV = 114.61, HVR = 0.89
# Iteration 208: HV = 114.60, HVR = 0.89
# Iteration 209: HV = 114.58, HVR = 0.89
# Iteration 210: HV = 114.58, HVR = 0.89
# Iteration 211: HV = 114.59, HVR = 0.89
# Iteration 212: HV = 114.55, HVR = 0.89
# Iteration 213: HV = 114.61, HVR = 0.89
# Iteration 214: HV = 114.53, HVR = 0.89
# Iteration 215: HV = 114.51, HVR = 0.89
# Iteration 216: HV = 114.50, HVR = 0.89
# Iteration 217: HV = 114.47, HVR = 0.89
# Iteration 218: HV = 114.43, HVR = 0.89
# Iteration 219: HV = 114.49, HVR = 0.89
# Iteration 220: HV = 114.41, HVR = 0.89
# Iteration 221: HV = 114.38, HVR = 0.89
# Iteration 222: HV = 114.45, HVR = 0.89
# Iteration 223: HV = 114.48, HVR = 0.89
# Iteration 224: HV = 114.51, HVR = 0.89
# Iteration 225: HV = 114.53, HVR = 0.89
# Iteration 226: HV = 114.51, HVR = 0.89
# Iteration 227: HV = 114.53, HVR = 0.89
# Iteration 228: HV = 114.52, HVR = 0.89
# Iteration 229: HV = 114.51, HVR = 0.89
# Iteration 230: HV = 114.45, HVR = 0.89
# Iteration 231: HV = 114.50, HVR = 0.89
# Iteration 232: HV = 114.48, HVR = 0.89
# Iteration 233: HV = 114.47, HVR = 0.89
# Iteration 234: HV = 114.48, HVR = 0.89
# Iteration 235: HV = 114.37, HVR = 0.89
# Iteration 236: HV = 114.39, HVR = 0.89
# Iteration 237: HV = 114.43, HVR = 0.89
# Iteration 238: HV = 114.30, HVR = 0.89
# Iteration 239: HV = 114.18, HVR = 0.89
# Iteration 240: HV = 114.22, HVR = 0.89
# Iteration 241: HV = 114.21, HVR = 0.89
# Iteration 242: HV = 114.22, HVR = 0.89
# Iteration 243: HV = 114.10, HVR = 0.89
# Iteration 244: HV = 114.05, HVR = 0.89
# Iteration 245: HV = 114.07, HVR = 0.89
# Iteration 246: HV = 114.07, HVR = 0.89
# Iteration 247: HV = 114.02, HVR = 0.89
# Iteration 248: HV = 114.07, HVR = 0.89
# Iteration 249: HV = 113.98, HVR = 0.89
# Iteration 250: HV = 113.99, HVR = 0.89
# Iteration 251: HV = 113.93, HVR = 0.88
# Iteration 252: HV = 113.92, HVR = 0.88
# Iteration 253: HV = 113.93, HVR = 0.88
# Iteration 254: HV = 113.88, HVR = 0.88
# Iteration 255: HV = 113.86, HVR = 0.88
# Iteration 256: HV = 113.84, HVR = 0.88
# Iteration 257: HV = 113.86, HVR = 0.88
# Iteration 258: HV = 113.85, HVR = 0.88
# Iteration 259: HV = 113.84, HVR = 0.88
# Iteration 260: HV = 113.82, HVR = 0.88
# Iteration 261: HV = 113.84, HVR = 0.88
# Iteration 262: HV = 113.86, HVR = 0.88
# Iteration 263: HV = 113.85, HVR = 0.88
# Iteration 264: HV = 113.87, HVR = 0.88
# Iteration 265: HV = 113.81, HVR = 0.88
# Iteration 266: HV = 113.82, HVR = 0.88
# Iteration 267: HV = 113.90, HVR = 0.88
# Iteration 268: HV = 113.86, HVR = 0.88
# Iteration 269: HV = 113.85, HVR = 0.88
# Iteration 270: HV = 113.89, HVR = 0.88
# Iteration 271: HV = 113.80, HVR = 0.88
# Iteration 272: HV = 113.81, HVR = 0.88
# Iteration 273: HV = 113.80, HVR = 0.88
# Iteration 274: HV = 113.75, HVR = 0.88
# Iteration 275: HV = 113.83, HVR = 0.88
# Iteration 276: HV = 113.80, HVR = 0.88
# Iteration 277: HV = 113.77, HVR = 0.88
# Iteration 278: HV = 113.83, HVR = 0.88
# Iteration 279: HV = 113.84, HVR = 0.88
# Iteration 280: HV = 113.78, HVR = 0.88
# Iteration 281: HV = 113.75, HVR = 0.88
# Iteration 282: HV = 113.73, HVR = 0.88
# Iteration 283: HV = 113.72, HVR = 0.88
# Iteration 284: HV = 113.69, HVR = 0.88
# Iteration 285: HV = 113.69, HVR = 0.88
# Iteration 286: HV = 113.70, HVR = 0.88
# Iteration 287: HV = 113.72, HVR = 0.88
# Iteration 288: HV = 113.77, HVR = 0.88
# Iteration 289: HV = 113.77, HVR = 0.88
# Iteration 290: HV = 113.77, HVR = 0.88
# Iteration 291: HV = 113.75, HVR = 0.88
# Iteration 292: HV = 113.68, HVR = 0.88
# Iteration 293: HV = 113.62, HVR = 0.88
# Iteration 294: HV = 113.65, HVR = 0.88
# Iteration 295: HV = 113.67, HVR = 0.88
# Iteration 296: HV = 113.63, HVR = 0.88
# Iteration 297: HV = 113.57, HVR = 0.88
# Iteration 298: HV = 113.63, HVR = 0.88
# Iteration 299: HV = 113.55, HVR = 0.88
# Iteration 300: HV = 113.54, HVR = 0.88
# Iteration 301: HV = 113.55, HVR = 0.88
# Iteration 302: HV = 113.52, HVR = 0.88
# Iteration 303: HV = 113.50, HVR = 0.88
# Iteration 304: HV = 113.50, HVR = 0.88
# Iteration 305: HV = 113.51, HVR = 0.88
# Iteration 306: HV = 113.49, HVR = 0.88
# Iteration 307: HV = 113.49, HVR = 0.88
# Iteration 308: HV = 113.50, HVR = 0.88
# Iteration 309: HV = 113.53, HVR = 0.88
# Iteration 310: HV = 113.57, HVR = 0.88
# Iteration 311: HV = 113.47, HVR = 0.88
# Iteration 312: HV = 113.44, HVR = 0.88
# Iteration 313: HV = 113.44, HVR = 0.88
# Iteration 314: HV = 113.43, HVR = 0.88
# Iteration 315: HV = 113.39, HVR = 0.88
# Iteration 316: HV = 113.39, HVR = 0.88
# Iteration 317: HV = 113.43, HVR = 0.88
# Iteration 318: HV = 113.44, HVR = 0.88
# Iteration 319: HV = 113.40, HVR = 0.88
# Iteration 320: HV = 113.38, HVR = 0.88
# Iteration 321: HV = 113.32, HVR = 0.88
# Iteration 322: HV = 113.41, HVR = 0.88
# Iteration 323: HV = 113.39, HVR = 0.88
# Iteration 324: HV = 113.37, HVR = 0.88
# Iteration 325: HV = 113.40, HVR = 0.88
# Iteration 326: HV = 113.40, HVR = 0.88
# Iteration 327: HV = 113.39, HVR = 0.88
# Iteration 328: HV = 113.32, HVR = 0.88
# Iteration 329: HV = 113.30, HVR = 0.88
# Iteration 330: HV = 113.28, HVR = 0.88
# Iteration 331: HV = 113.27, HVR = 0.88
# Iteration 332: HV = 113.26, HVR = 0.88
# Iteration 333: HV = 113.26, HVR = 0.88
# Iteration 334: HV = 113.26, HVR = 0.88
# Iteration 335: HV = 113.29, HVR = 0.88
# Iteration 336: HV = 113.25, HVR = 0.88
# Iteration 337: HV = 113.26, HVR = 0.88
# Iteration 338: HV = 113.25, HVR = 0.88
# Iteration 339: HV = 113.24, HVR = 0.88
# Iteration 340: HV = 113.20, HVR = 0.88
# Iteration 341: HV = 113.26, HVR = 0.88
# Iteration 342: HV = 113.24, HVR = 0.88
# Iteration 343: HV = 113.19, HVR = 0.88
# Iteration 344: HV = 113.21, HVR = 0.88
# Iteration 345: HV = 113.21, HVR = 0.88
# Iteration 346: HV = 113.22, HVR = 0.88
# Iteration 347: HV = 113.21, HVR = 0.88
# Iteration 348: HV = 113.12, HVR = 0.88
# Iteration 349: HV = 113.15, HVR = 0.88
# Iteration 350: HV = 113.14, HVR = 0.88
# Iteration 351: HV = 113.13, HVR = 0.88
# Iteration 352: HV = 113.15, HVR = 0.88
# Iteration 353: HV = 113.14, HVR = 0.88
# Iteration 354: HV = 113.15, HVR = 0.88
# Iteration 355: HV = 113.12, HVR = 0.88
# Iteration 356: HV = 113.13, HVR = 0.88
# Iteration 357: HV = 113.15, HVR = 0.88
# Iteration 358: HV = 113.15, HVR = 0.88
# Iteration 359: HV = 113.09, HVR = 0.88
# Iteration 360: HV = 113.11, HVR = 0.88
# Iteration 361: HV = 113.10, HVR = 0.88
# Iteration 362: HV = 113.07, HVR = 0.88
# Iteration 363: HV = 113.06, HVR = 0.88
# Iteration 364: HV = 113.07, HVR = 0.88
# Iteration 365: HV = 113.06, HVR = 0.88
# Iteration 366: HV = 113.11, HVR = 0.88
# Iteration 367: HV = 113.08, HVR = 0.88
# Iteration 368: HV = 113.10, HVR = 0.88
# Iteration 369: HV = 113.09, HVR = 0.88
# Iteration 370: HV = 113.08, HVR = 0.88
# Iteration 371: HV = 113.09, HVR = 0.88
# Iteration 372: HV = 113.09, HVR = 0.88
# Iteration 373: HV = 113.11, HVR = 0.88
# Iteration 374: HV = 113.08, HVR = 0.88
# Iteration 375: HV = 113.13, HVR = 0.88
# Iteration 376: HV = 113.16, HVR = 0.88
# Iteration 377: HV = 113.14, HVR = 0.88
# Iteration 378: HV = 113.16, HVR = 0.88
# Iteration 379: HV = 113.16, HVR = 0.88
# Iteration 380: HV = 113.14, HVR = 0.88
# Iteration 381: HV = 113.13, HVR = 0.88
# Iteration 382: HV = 113.07, HVR = 0.88
# Iteration 383: HV = 113.13, HVR = 0.88
# Iteration 384: HV = 113.15, HVR = 0.88
# Iteration 385: HV = 113.16, HVR = 0.88
# Iteration 386: HV = 113.14, HVR = 0.88
# Iteration 387: HV = 113.08, HVR = 0.88
# Iteration 388: HV = 113.09, HVR = 0.88
# Iteration 389: HV = 113.10, HVR = 0.88
# Iteration 390: HV = 113.09, HVR = 0.88
# Iteration 391: HV = 113.09, HVR = 0.88
# Iteration 392: HV = 113.09, HVR = 0.88
# Iteration 393: HV = 113.08, HVR = 0.88
# Iteration 394: HV = 113.09, HVR = 0.88
# Iteration 395: HV = 113.07, HVR = 0.88
# Iteration 396: HV = 113.03, HVR = 0.88
# Iteration 397: HV = 113.07, HVR = 0.88
# Iteration 398: HV = 113.05, HVR = 0.88
# Iteration 399: HV = 113.08, HVR = 0.88
# Iteration 400: HV = 113.01, HVR = 0.88
# Iteration 401: HV = 113.07, HVR = 0.88
# Iteration 402: HV = 113.04, HVR = 0.88
# Iteration 403: HV = 113.04, HVR = 0.88
# Iteration 404: HV = 113.00, HVR = 0.88
# Iteration 405: HV = 113.04, HVR = 0.88
# Iteration 406: HV = 113.03, HVR = 0.88
# Iteration 407: HV = 113.02, HVR = 0.88
# Iteration 408: HV = 113.00, HVR = 0.88
# Iteration 409: HV = 112.99, HVR = 0.88
# Iteration 410: HV = 112.98, HVR = 0.88
# Iteration 411: HV = 113.01, HVR = 0.88
# Iteration 412: HV = 113.00, HVR = 0.88
# Iteration 413: HV = 113.03, HVR = 0.88
# Iteration 414: HV = 112.99, HVR = 0.88
# Iteration 415: HV = 113.01, HVR = 0.88
# Iteration 416: HV = 113.04, HVR = 0.88
# Iteration 417: HV = 113.07, HVR = 0.88
# Iteration 418: HV = 113.02, HVR = 0.88
# Iteration 419: HV = 112.99, HVR = 0.88
# Iteration 420: HV = 113.00, HVR = 0.88
# Iteration 421: HV = 113.03, HVR = 0.88
# Iteration 422: HV = 113.03, HVR = 0.88
# Iteration 423: HV = 112.98, HVR = 0.88
# Iteration 424: HV = 113.01, HVR = 0.88
# Iteration 425: HV = 113.04, HVR = 0.88
# Iteration 426: HV = 113.02, HVR = 0.88
# Iteration 427: HV = 113.00, HVR = 0.88
# Iteration 428: HV = 113.08, HVR = 0.88
# Iteration 429: HV = 113.02, HVR = 0.88
# Iteration 430: HV = 113.01, HVR = 0.88
# Iteration 431: HV = 113.02, HVR = 0.88
# Iteration 432: HV = 112.99, HVR = 0.88
# Iteration 433: HV = 113.02, HVR = 0.88
# Iteration 434: HV = 112.98, HVR = 0.88
# Iteration 435: HV = 112.96, HVR = 0.88
# Iteration 436: HV = 112.99, HVR = 0.88
# Iteration 437: HV = 112.96, HVR = 0.88
# Iteration 438: HV = 113.01, HVR = 0.88
# Iteration 439: HV = 113.01, HVR = 0.88
# Iteration 440: HV = 113.02, HVR = 0.88
# Iteration 441: HV = 112.95, HVR = 0.88
# Iteration 442: HV = 113.01, HVR = 0.88
# Iteration 443: HV = 112.93, HVR = 0.88
# Iteration 444: HV = 112.95, HVR = 0.88
# Iteration 445: HV = 112.95, HVR = 0.88
# Iteration 446: HV = 112.97, HVR = 0.88
# Iteration 447: HV = 112.98, HVR = 0.88
# Iteration 448: HV = 112.96, HVR = 0.88
# Iteration 449: HV = 112.98, HVR = 0.88
# Iteration 450: HV = 112.95, HVR = 0.88
# Iteration 451: HV = 112.97, HVR = 0.88
# Iteration 452: HV = 112.94, HVR = 0.88
# Iteration 453: HV = 112.94, HVR = 0.88
# Iteration 454: HV = 112.94, HVR = 0.88
# Iteration 455: HV = 112.93, HVR = 0.88
# Iteration 456: HV = 112.92, HVR = 0.88
# Iteration 457: HV = 112.98, HVR = 0.88
# Iteration 458: HV = 112.91, HVR = 0.88
# Iteration 459: HV = 112.91, HVR = 0.88
# Iteration 460: HV = 112.90, HVR = 0.88
# Iteration 461: HV = 112.92, HVR = 0.88
# Iteration 462: HV = 112.93, HVR = 0.88
# Iteration 463: HV = 112.97, HVR = 0.88
# Iteration 464: HV = 112.97, HVR = 0.88
# Iteration 465: HV = 112.94, HVR = 0.88
# Iteration 466: HV = 112.96, HVR = 0.88
# Iteration 467: HV = 112.92, HVR = 0.88
# Iteration 468: HV = 112.88, HVR = 0.88
# Iteration 469: HV = 112.89, HVR = 0.88
# Iteration 470: HV = 112.87, HVR = 0.88
# Iteration 471: HV = 112.88, HVR = 0.88
# Iteration 472: HV = 112.90, HVR = 0.88
# Iteration 473: HV = 112.91, HVR = 0.88
# Iteration 474: HV = 112.90, HVR = 0.88
# Iteration 475: HV = 112.95, HVR = 0.88
# Iteration 476: HV = 112.92, HVR = 0.88
# Iteration 477: HV = 112.87, HVR = 0.88
# Iteration 478: HV = 112.89, HVR = 0.88
# Iteration 479: HV = 112.85, HVR = 0.88
# Iteration 480: HV = 112.85, HVR = 0.88
# Iteration 481: HV = 112.88, HVR = 0.88
# Iteration 482: HV = 112.90, HVR = 0.88
# Iteration 483: HV = 112.87, HVR = 0.88
# Iteration 484: HV = 112.92, HVR = 0.88
# Iteration 485: HV = 112.87, HVR = 0.88
# Iteration 486: HV = 112.86, HVR = 0.88
# Iteration 487: HV = 112.98, HVR = 0.88
# Iteration 488: HV = 112.88, HVR = 0.88
# Iteration 489: HV = 112.86, HVR = 0.88
# Iteration 490: HV = 112.87, HVR = 0.88
# Iteration 491: HV = 112.92, HVR = 0.88
# Iteration 492: HV = 112.89, HVR = 0.88
# Iteration 493: HV = 112.86, HVR = 0.88
# Iteration 494: HV = 112.96, HVR = 0.88
# Iteration 495: HV = 112.92, HVR = 0.88
# Iteration 496: HV = 112.88, HVR = 0.88
# Iteration 497: HV = 112.93, HVR = 0.88
# Iteration 498: HV = 112.91, HVR = 0.88
# Iteration 499: HV = 112.94, HVR = 0.88
# CPU times: user 15min 16s, sys: 25.2 s, total: 15min 42s
# Wall time: 14min 49s

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
