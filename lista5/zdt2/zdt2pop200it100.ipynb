# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
X = np.linspace(0, 1, 100)
Y = 1 - X**2

plt.figure(figsize=(12, 8))
plt.plot(X, Y, 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT2Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt2_definitions import ZDT2Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT2Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = []
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT2Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics.append((hv, hvr, ranks, crowding_distances, objectives))

# %%
def plot_PF(results):
    PF = np.array([i.objectives for i in results])

    plt.figure(figsize=(12, 8))
    plt.plot(PF[:, 0], PF[:, 1], 'ro')
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.title('Pareto Front')
    plt.show()

# %%
# %%time

# pop 50 - dośc rzadki front

solver = Evolution(ZDT(ZDT2Definitions()), 100, 200)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()

plot_PF(results)
# Out:
# Iteration 000: HV = 71.15, HVR = 0.59
# Iteration 001: HV = 72.27, HVR = 0.60
# Iteration 002: HV = 72.81, HVR = 0.61
# Iteration 003: HV = 76.96, HVR = 0.64
# Iteration 004: HV = 77.61, HVR = 0.64
# Iteration 005: HV = 78.13, HVR = 0.65
# Iteration 006: HV = 78.84, HVR = 0.66
# Iteration 007: HV = 80.32, HVR = 0.67
# Iteration 008: HV = 80.80, HVR = 0.67
# Iteration 009: HV = 82.12, HVR = 0.68
# Iteration 010: HV = 82.90, HVR = 0.69
# Iteration 011: HV = 83.44, HVR = 0.69
# Iteration 012: HV = 84.37, HVR = 0.70
# Iteration 013: HV = 84.88, HVR = 0.71
# Iteration 014: HV = 85.73, HVR = 0.71
# Iteration 015: HV = 87.45, HVR = 0.73
# Iteration 016: HV = 88.58, HVR = 0.74
# Iteration 017: HV = 89.06, HVR = 0.74
# Iteration 018: HV = 89.38, HVR = 0.74
# Iteration 019: HV = 91.08, HVR = 0.76
# Iteration 020: HV = 90.68, HVR = 0.75
# Iteration 021: HV = 91.62, HVR = 0.76
# Iteration 022: HV = 91.76, HVR = 0.76
# Iteration 023: HV = 93.02, HVR = 0.77
# Iteration 024: HV = 92.52, HVR = 0.77
# Iteration 025: HV = 95.62, HVR = 0.79
# Iteration 026: HV = 94.97, HVR = 0.79
# Iteration 027: HV = 95.12, HVR = 0.79
# Iteration 028: HV = 95.62, HVR = 0.79
# Iteration 029: HV = 96.65, HVR = 0.80
# Iteration 030: HV = 97.10, HVR = 0.81
# Iteration 031: HV = 97.33, HVR = 0.81
# Iteration 032: HV = 98.03, HVR = 0.81
# Iteration 033: HV = 97.67, HVR = 0.81
# Iteration 034: HV = 98.29, HVR = 0.82
# Iteration 035: HV = 98.09, HVR = 0.82
# Iteration 036: HV = 99.17, HVR = 0.82
# Iteration 037: HV = 99.17, HVR = 0.82
# Iteration 038: HV = 100.34, HVR = 0.83
# Iteration 039: HV = 100.74, HVR = 0.84
# Iteration 040: HV = 100.98, HVR = 0.84
# Iteration 041: HV = 101.28, HVR = 0.84
# Iteration 042: HV = 101.82, HVR = 0.85
# Iteration 043: HV = 102.19, HVR = 0.85
# Iteration 044: HV = 102.56, HVR = 0.85
# Iteration 045: HV = 102.91, HVR = 0.86
# Iteration 046: HV = 103.02, HVR = 0.86
# Iteration 047: HV = 103.16, HVR = 0.86
# Iteration 048: HV = 103.29, HVR = 0.86
# Iteration 049: HV = 103.74, HVR = 0.86
# Iteration 050: HV = 104.50, HVR = 0.87
# Iteration 051: HV = 104.55, HVR = 0.87
# Iteration 052: HV = 104.42, HVR = 0.87
# Iteration 053: HV = 104.36, HVR = 0.87
# Iteration 054: HV = 104.62, HVR = 0.87
# Iteration 055: HV = 104.57, HVR = 0.87
# Iteration 056: HV = 104.88, HVR = 0.87
# Iteration 057: HV = 104.88, HVR = 0.87
# Iteration 058: HV = 104.85, HVR = 0.87
# Iteration 059: HV = 105.38, HVR = 0.88
# Iteration 060: HV = 105.51, HVR = 0.88
# Iteration 061: HV = 105.56, HVR = 0.88
# Iteration 062: HV = 105.80, HVR = 0.88
# Iteration 063: HV = 106.04, HVR = 0.88
# Iteration 064: HV = 106.10, HVR = 0.88
# Iteration 065: HV = 106.18, HVR = 0.88
# Iteration 066: HV = 106.37, HVR = 0.88
# Iteration 067: HV = 106.46, HVR = 0.88
# Iteration 068: HV = 106.57, HVR = 0.89
# Iteration 069: HV = 106.63, HVR = 0.89
# Iteration 070: HV = 106.85, HVR = 0.89
# Iteration 071: HV = 106.93, HVR = 0.89
# Iteration 072: HV = 106.98, HVR = 0.89
# Iteration 073: HV = 106.95, HVR = 0.89
# Iteration 074: HV = 107.06, HVR = 0.89
# Iteration 075: HV = 107.06, HVR = 0.89
# Iteration 076: HV = 107.16, HVR = 0.89
# Iteration 077: HV = 107.28, HVR = 0.89
# Iteration 078: HV = 107.31, HVR = 0.89
# Iteration 079: HV = 107.33, HVR = 0.89
# Iteration 080: HV = 107.38, HVR = 0.89
# Iteration 081: HV = 107.40, HVR = 0.89
# Iteration 082: HV = 107.37, HVR = 0.89
# Iteration 083: HV = 107.44, HVR = 0.89
# Iteration 084: HV = 107.52, HVR = 0.89
# Iteration 085: HV = 107.53, HVR = 0.89
# Iteration 086: HV = 107.54, HVR = 0.89
# Iteration 087: HV = 107.64, HVR = 0.89
# Iteration 088: HV = 107.61, HVR = 0.89
# Iteration 089: HV = 107.63, HVR = 0.89
# Iteration 090: HV = 107.68, HVR = 0.89
# Iteration 091: HV = 107.73, HVR = 0.90
# Iteration 092: HV = 107.75, HVR = 0.90
# Iteration 093: HV = 107.77, HVR = 0.90
# Iteration 094: HV = 107.87, HVR = 0.90
# Iteration 095: HV = 107.89, HVR = 0.90
# Iteration 096: HV = 107.90, HVR = 0.90
# Iteration 097: HV = 107.93, HVR = 0.90
# Iteration 098: HV = 107.93, HVR = 0.90
# Iteration 099: HV = 107.91, HVR = 0.90
# CPU times: user 3min 16s, sys: 6.34 s, total: 3min 23s
# Wall time: 3min 11s

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
