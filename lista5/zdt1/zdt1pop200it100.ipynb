# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
X = np.linspace(0, 1, 100)
Y = 1 - np.sqrt(X)

plt.figure(figsize=(12, 8))
plt.plot(X, Y, 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT1Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt1_definitions import ZDT1Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT1Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = []
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT1Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics.append((hv, hvr, ranks, crowding_distances, objectives))

# %%
def plot_PF(results):
    PF = np.array([i.objectives for i in results])

    plt.figure(figsize=(12, 8))
    plt.plot(PF[:, 0], PF[:, 1], 'ro')
    plt.xlabel('Objective 1')
    plt.ylabel('Objective 2')
    plt.title('Pareto Front')
    plt.show()

# %%
# %%time

solver = Evolution(ZDT(ZDT1Definitions()), 100, 200)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()

plot_PF(results)
# Out:
# Iteration 000: HV = 76.92, HVR = 0.64
# Iteration 001: HV = 78.51, HVR = 0.65
# Iteration 002: HV = 80.05, HVR = 0.66
# Iteration 003: HV = 81.26, HVR = 0.67
# Iteration 004: HV = 82.23, HVR = 0.68
# Iteration 005: HV = 84.04, HVR = 0.70
# Iteration 006: HV = 85.35, HVR = 0.71
# Iteration 007: HV = 85.50, HVR = 0.71
# Iteration 008: HV = 88.27, HVR = 0.73
# Iteration 009: HV = 87.08, HVR = 0.72
# Iteration 010: HV = 89.63, HVR = 0.74
# Iteration 011: HV = 91.81, HVR = 0.76
# Iteration 012: HV = 92.03, HVR = 0.76
# Iteration 013: HV = 93.63, HVR = 0.78
# Iteration 014: HV = 93.89, HVR = 0.78
# Iteration 015: HV = 95.37, HVR = 0.79
# Iteration 016: HV = 96.08, HVR = 0.80
# Iteration 017: HV = 96.63, HVR = 0.80
# Iteration 018: HV = 97.34, HVR = 0.81
# Iteration 019: HV = 98.01, HVR = 0.81
# Iteration 020: HV = 98.74, HVR = 0.82
# Iteration 021: HV = 99.65, HVR = 0.83
# Iteration 022: HV = 100.00, HVR = 0.83
# Iteration 023: HV = 100.72, HVR = 0.83
# Iteration 024: HV = 101.38, HVR = 0.84
# Iteration 025: HV = 101.71, HVR = 0.84
# Iteration 026: HV = 102.03, HVR = 0.85
# Iteration 027: HV = 102.96, HVR = 0.85
# Iteration 028: HV = 103.65, HVR = 0.86
# Iteration 029: HV = 103.92, HVR = 0.86
# Iteration 030: HV = 104.46, HVR = 0.87
# Iteration 031: HV = 105.06, HVR = 0.87
# Iteration 032: HV = 105.57, HVR = 0.87
# Iteration 033: HV = 105.76, HVR = 0.88
# Iteration 034: HV = 105.84, HVR = 0.88
# Iteration 035: HV = 106.21, HVR = 0.88
# Iteration 036: HV = 106.56, HVR = 0.88
# Iteration 037: HV = 106.98, HVR = 0.89
# Iteration 038: HV = 107.52, HVR = 0.89
# Iteration 039: HV = 107.87, HVR = 0.89
# Iteration 040: HV = 108.11, HVR = 0.90
# Iteration 041: HV = 108.23, HVR = 0.90
# Iteration 042: HV = 108.47, HVR = 0.90
# Iteration 043: HV = 108.77, HVR = 0.90
# Iteration 044: HV = 109.00, HVR = 0.90
# Iteration 045: HV = 109.15, HVR = 0.90
# Iteration 046: HV = 109.21, HVR = 0.91
# Iteration 047: HV = 109.20, HVR = 0.91
# Iteration 048: HV = 109.51, HVR = 0.91
# Iteration 049: HV = 109.64, HVR = 0.91
# Iteration 050: HV = 109.74, HVR = 0.91
# Iteration 051: HV = 109.79, HVR = 0.91
# Iteration 052: HV = 109.95, HVR = 0.91
# Iteration 053: HV = 110.13, HVR = 0.91
# Iteration 054: HV = 110.11, HVR = 0.91
# Iteration 055: HV = 110.23, HVR = 0.91
# Iteration 056: HV = 110.25, HVR = 0.91
# Iteration 057: HV = 110.36, HVR = 0.91
# Iteration 058: HV = 110.39, HVR = 0.91
# Iteration 059: HV = 110.40, HVR = 0.91
# Iteration 060: HV = 110.52, HVR = 0.92
# Iteration 061: HV = 110.59, HVR = 0.92
# Iteration 062: HV = 110.63, HVR = 0.92
# Iteration 063: HV = 110.68, HVR = 0.92
# Iteration 064: HV = 110.70, HVR = 0.92
# Iteration 065: HV = 110.76, HVR = 0.92
# Iteration 066: HV = 110.82, HVR = 0.92
# Iteration 067: HV = 110.96, HVR = 0.92
# Iteration 068: HV = 111.07, HVR = 0.92
# Iteration 069: HV = 111.10, HVR = 0.92
# Iteration 070: HV = 111.08, HVR = 0.92
# Iteration 071: HV = 111.06, HVR = 0.92
# Iteration 072: HV = 111.11, HVR = 0.92
# Iteration 073: HV = 111.19, HVR = 0.92
# Iteration 074: HV = 111.20, HVR = 0.92
# Iteration 075: HV = 111.24, HVR = 0.92
# Iteration 076: HV = 111.29, HVR = 0.92
# Iteration 077: HV = 111.28, HVR = 0.92
# Iteration 078: HV = 111.37, HVR = 0.92
# Iteration 079: HV = 111.41, HVR = 0.92
# Iteration 080: HV = 111.44, HVR = 0.92
# Iteration 081: HV = 111.45, HVR = 0.92
# Iteration 082: HV = 111.54, HVR = 0.92
# Iteration 083: HV = 111.53, HVR = 0.92
# Iteration 084: HV = 111.57, HVR = 0.92
# Iteration 085: HV = 111.58, HVR = 0.92
# Iteration 086: HV = 111.64, HVR = 0.93
# Iteration 087: HV = 111.67, HVR = 0.93
# Iteration 088: HV = 111.63, HVR = 0.93
# Iteration 089: HV = 111.67, HVR = 0.93
# Iteration 090: HV = 111.71, HVR = 0.93
# Iteration 091: HV = 111.73, HVR = 0.93
# Iteration 092: HV = 111.79, HVR = 0.93
# Iteration 093: HV = 111.76, HVR = 0.93
# Iteration 094: HV = 111.78, HVR = 0.93
# Iteration 095: HV = 111.77, HVR = 0.93
# Iteration 096: HV = 111.78, HVR = 0.93
# Iteration 097: HV = 111.76, HVR = 0.93
# Iteration 098: HV = 111.77, HVR = 0.93
# Iteration 099: HV = 111.78, HVR = 0.93
# CPU times: user 2min 43s, sys: 5.97 s, total: 2min 49s
# Wall time: 2min 38s

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
