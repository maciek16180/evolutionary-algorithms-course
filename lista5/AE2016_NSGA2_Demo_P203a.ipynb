# %% [markdown]
# # Optymalizacja wielokryterialna
#
# Notebook pokazuje przykład działania algorytmu NSGA-II na benchmarku ZDT3.
#
# Literatura dodatkowa:
#
# [1] E. Zitzler, K. Deb, L. Thiele, Comparison of Multiobjective Evolutionary Algorithms: Empirical Results, Evolutionary Computation, vol 8, no 2, 2000, pp. 173-195. [http://www.tik.ee.ethz.ch/sop/publicationListFiles/zdt2000a.pdf]
#
# [2] Multi-objective Benchmark Problems. [http://www.tik.ee.ethz.ch/sop/download/supplementary/testproblems/]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Działanie NSGA-II na ZDT3

# %% [markdown]
# ### Problem ZDT3
#
# Problem ZDT3 to dość popularny problem testowy dla optymalizacji wielokryterialnej.
#
# Przestrzeń poszukiwań: $\Omega = [0, 1]^d$.
#
# Dwa kryteria (oba minimalizujemy):
#
# $$f_1(\mathbf{x}) = x_1,$$
#
# $$f_2(\mathbf{x}) = g(\mathbf{x}) [1 - \sqrt{x_1 / g(\mathbf{x})} - x_1 / g(\mathbf{x}) \sin(10 \pi x_1)],$$
# gdzie $g(\mathbf{x}) = 1 + \frac{9}{d-1}\sum_{i=2}^d x_i$.

# %% [markdown]
# ### Dokładny front Pareto dla ZDT3
#
# Znane są wzory na dokładny front Pareto dla ZDT3 (patrz [1] lub [2]).

# %%
F = np.array([[0.0000000000, 0.0830015349],
              [0.1822287280, 0.2577623634],
              [0.4093136748, 0.4538821041],
              [0.6183967944, 0.6525117038],
              [0.8233317983, 0.8518328654]])

r = 10
X = (np.tile(np.linspace(0, 1, r), [F.shape[0], 1]) * (F[:, 1] - F[:, 0])[np.newaxis].T + F[:, 0][np.newaxis].T)
Y = 1 - np.sqrt(X) - X * np.sin(10 * np.pi * X)

plt.figure(figsize=(12, 8))
for i in xrange(F.shape[0]):
    plt.plot(X[i, :].ravel(), Y[i, :].ravel(), 'r-')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wyznaczanie frontu Pareto algorytmem NSGA-II

# %%
# %%time

import sys

sys.path.append('nsga2/')

from metrics.problems.zdt import ZDT3Metrics
from nsga2.evolution import Evolution
from nsga2.problems.zdt import ZDT
from nsga2.problems.zdt.zdt3_definitions import ZDT3Definitions

def print_statistics(population, iteration):
    PF = population.fronts[0]
    metrics = ZDT3Metrics()
    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))

statistics = {}
def log_statistics(population, iteration):
    ranks = [individual.rank for individual in population]
    crowding_distances = [individual.crowding_distance for individual in population]
    objectives = [individual.objectives for individual in population]

    pareto_front = population.fronts[0]
    metrics = ZDT3Metrics()
    hv = metrics.HV(pareto_front)
    hvr = metrics.HVR(pareto_front)

    statistics[iteration] = hv, hvr, ranks, crowding_distances, objectives

solver = Evolution(ZDT(ZDT3Definitions()), 200, 250)
solver.register_on_new_generation(print_statistics)
solver.register_on_new_generation(log_statistics)
results = solver.evolve()
# Out:
# Iteration 000: HV = 81.60, HVR = 0.63
# Iteration 001: HV = 81.21, HVR = 0.63
# Iteration 002: HV = 82.99, HVR = 0.64
# Iteration 003: HV = 83.23, HVR = 0.65
# Iteration 004: HV = 86.45, HVR = 0.67
# Iteration 005: HV = 87.20, HVR = 0.68
# Iteration 006: HV = 87.39, HVR = 0.68
# Iteration 007: HV = 91.09, HVR = 0.71
# Iteration 008: HV = 90.57, HVR = 0.70
# Iteration 009: HV = 90.96, HVR = 0.71
# Iteration 010: HV = 91.66, HVR = 0.71
# Iteration 011: HV = 93.49, HVR = 0.73
# Iteration 012: HV = 95.51, HVR = 0.74
# Iteration 013: HV = 95.45, HVR = 0.74
# Iteration 014: HV = 95.83, HVR = 0.74
# Iteration 015: HV = 97.01, HVR = 0.75
# Iteration 016: HV = 96.94, HVR = 0.75
# Iteration 017: HV = 97.65, HVR = 0.76
# Iteration 018: HV = 98.98, HVR = 0.77
# Iteration 019: HV = 100.57, HVR = 0.78
# Iteration 020: HV = 100.15, HVR = 0.78
# Iteration 021: HV = 99.81, HVR = 0.78
# Iteration 022: HV = 101.02, HVR = 0.78
# Iteration 023: HV = 102.01, HVR = 0.79
# Iteration 024: HV = 103.01, HVR = 0.80
# Iteration 025: HV = 103.62, HVR = 0.80
# Iteration 026: HV = 105.07, HVR = 0.82
# Iteration 027: HV = 104.90, HVR = 0.81
# Iteration 028: HV = 106.25, HVR = 0.83
# Iteration 029: HV = 105.78, HVR = 0.82
# Iteration 030: HV = 106.63, HVR = 0.83
# Iteration 031: HV = 107.14, HVR = 0.83
# Iteration 032: HV = 107.34, HVR = 0.83
# Iteration 033: HV = 107.33, HVR = 0.83
# Iteration 034: HV = 107.85, HVR = 0.84
# Iteration 035: HV = 108.17, HVR = 0.84
# Iteration 036: HV = 108.15, HVR = 0.84
# Iteration 037: HV = 108.65, HVR = 0.84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8b0bb8dc8973> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'\nimport sys\n\nsys.path.append(\'nsga2/\')\n\nfrom metrics.problems.zdt import ZDT3Metrics\nfrom nsga2.evolution import Evolution\nfrom nsga2.problems.zdt import ZDT\nfrom nsga2.problems.zdt.zdt3_definitions import ZDT3Definitions\n\ndef print_statistics(population, iteration):\n    PF = population.fronts[0]\n    metrics = ZDT3Metrics()\n    print("Iteration %03d: HV = %0.2f, HVR = %0.2f" % (iteration, metrics.HV(PF), metrics.HVR(PF)))\n\nstatistics = {}\ndef log_statistics(population, iteration):\n    ranks = [individual.rank for individual in population]\n    crowding_distances = [individual.crowding_distance for individual in population]\n    objectives = [individual.objectives for individual in population]\n\n    pareto_front = population.fronts[0]\n    metrics = ZDT3Metrics()\n    hv = metrics.HV(pareto_front)\n    hvr = metrics.HVR(pareto_front)\n\n    statistics[iteration] = hv, hvr, ranks, crowding_distances, objectives\n\nsolver = Evolution(ZDT(ZDT3Definitions()), 200, 250)\nsolver.register_on_new_generation(print_statistics)\nsolver.register_on_new_generation(log_statistics)\nresults = solver.evolve()')
#
# /home/maciek/.anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /home/maciek/.anaconda2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/maciek/.anaconda2/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# /home/maciek/Desktop/evolutionary-algorithms-course/lista5/nsga2/nsga2/evolution.py in evolve(self)
#      28         for i in range(self.num_of_generations):
#      29             self.population.extend(children)
# ---> 30             self.utils.fast_nondominated_sort(self.population)
#      31             new_population = Population()
#      32             front_num = 0
#
# /home/maciek/Desktop/evolutionary-algorithms-course/lista5/nsga2/nsga2/utils.py in fast_nondominated_sort(self, population)
#      25                 if individual.dominates(other_individual):
#      26                     individual.dominated_solutions.add(other_individual)
# ---> 27                 elif other_individual.dominates(individual):
#      28                     individual.domination_count += 1
#      29             if individual.domination_count == 0:
#
# /home/maciek/Desktop/evolutionary-algorithms-course/lista5/nsga2/nsga2/problems/zdt/__init__.py in __dominates(self, individual2, individual1)
#      17     def __dominates(self, individual2, individual1):
#      18         worse_than_other = self.zdt_definitions.f1(individual1) <= self.zdt_definitions.f1(individual2) and self.zdt_definitions.f2(individual1) <= self.zdt_definitions.f2(individual2)
# ---> 19         better_than_other = self.zdt_definitions.f1(individual1) < self.zdt_definitions.f1(individual2) or self.zdt_definitions.f2(individual1) < self.zdt_definitions.f2(individual2)
#      20         return worse_than_other and better_than_other
#      21
#
# /home/maciek/Desktop/evolutionary-algorithms-course/lista5/nsga2/nsga2/problems/zdt/zdt3_definitions.py in f2(self, individual)
#      14         sigma = sum(individual.features[1:])
#      15         g = 1 + sigma*9/(self.n - 1)
# ---> 16         f1 = self.f1(individual)
#      17         h = 1 - math.sqrt(f1/g) - (f1/g)*math.sin(10*math.pi*f1)
#      18         return g*h
#
# KeyboardInterrupt:

# %% [markdown]
# ### Wykres uzyskanego (ostatecznego) frontu Pareto

# %%
PF = np.array([i.objectives for i in results])

plt.figure(figsize=(12, 8))
plt.plot(PF[:, 0], PF[:, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Pareto Front')
plt.show()

# %% [markdown]
# ### Wykres HV i HVR

# %%
HV = np.array([statistics[i][0] for i in xrange(len(statistics))])
HVR = np.array([statistics[i][1] for i in xrange(len(statistics))])

plt.figure(figsize=(12, 8))
plt.plot(HV, 'r-')
plt.xlabel('iteration')
plt.ylabel('HV')
plt.title('HV')
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(HVR, 'r-')
plt.xlabel('iteration')
plt.ylabel('HVR')
plt.title('HVR')
plt.show()

# %% [markdown]
# ### Wykres przykładowej populacji (ze wskazanej iteracji)

# %%
iteration = 1 # len(statistics)-1

ranks = np.array(statistics[iteration][2])
objectives = np.array(statistics[iteration][4])

PF0 = (ranks == 0)
PF1 = (ranks == 1)
PF2 = (ranks == 2)

plt.figure(figsize=(12, 8))
plt.plot(objectives[:, 0], objectives[:, 1], 'ko')
plt.plot(objectives[PF2, 0], objectives[PF2, 1], 'bo')
plt.plot(objectives[PF1, 0], objectives[PF1, 1], 'go')
plt.plot(objectives[PF0, 0], objectives[PF0, 1], 'ro')
plt.xlabel('Objective 1')
plt.ylabel('Objective 2')
plt.title('Population')
plt.show()
